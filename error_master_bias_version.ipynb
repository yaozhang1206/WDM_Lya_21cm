# %%
import theory_P_lyas_fur_yao_bias_version as th_y
import numpy as np
import matplotlib.pyplot as plt
import theory_P_lyas_fur_yao_mh as th_y_mh
from scipy.interpolate import interp2d

# %%
z_arinyo = [2.2, 2.4, 2.6, 2.8, 3.0]
sigmas = [0.64, 0.76, 0.8778]
beta_rsd_zs = [1.163, 1.284, 1.405, 1.137, 1.257, 1.385, 1.094, 1.219, 1.343, 1.035, 1.161, 1.284, 0.965, 1.086, 1.205]
print(len(z_arinyo),len(sigmas),len(beta_rsd_zs))
beta_rsd = interp2d(z_arinyo, sigmas, beta_rsd_zs)
# Out:
# 5 3 15

# %%
mini_halos = False

# %%
if mini_halos == True: 
    # nomenclature to deal with this procedure model_21cmrealization_gadgetrealization, e.g. 
    # r1_ave_3keV uses gadget mean.
    
    # need to do average Gadget and all the 21cm fast realizations
    r1_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_mh_r1_cdm', 'gadget_ave_cdm')
    r2_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_mh_r2_cdm', 'gadget_ave_cdm')
    r3_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_mh_r3_cdm', 'gadget_ave_cdm')
    r4_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_mh_r4_cdm', 'gadget_ave_cdm')

    r1_ave_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cmfast_mh_r1_wdm3', 'gadget_ave_3keV')
    r2_ave_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cmfast_mh_r2_wdm3', 'gadget_ave_3keV')
    r3_ave_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cmfast_mh_r3_wdm3', 'gadget_ave_3keV')
    r4_ave_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cmfast_mh_r4_wdm3', 'gadget_ave_3keV')

    r1_ave_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cmfast_mh_r1_wdm4', 'gadget_ave_4keV')
    r2_ave_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cmfast_mh_r2_wdm4', 'gadget_ave_4keV')
    r3_ave_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cmfast_mh_r3_wdm4', 'gadget_ave_4keV')
    r4_ave_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cmfast_mh_r4_wdm4', 'gadget_ave_4keV')

    r1_ave_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cmfast_mh_r1_wdm6', 'gadget_ave_6keV')
    r2_ave_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cmfast_mh_r2_wdm6', 'gadget_ave_6keV')
    r3_ave_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cmfast_mh_r3_wdm6', 'gadget_ave_6keV')
    r4_ave_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cmfast_mh_r4_wdm6', 'gadget_ave_6keV')

    r1_ave_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cmfast_mh_r1_wdm9', 'gadget_ave_9keV')
    r2_ave_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cmfast_mh_r2_wdm9', 'gadget_ave_9keV')
    r3_ave_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cmfast_mh_r3_wdm9', 'gadget_ave_9keV')
    r4_ave_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cmfast_mh_r4_wdm9', 'gadget_ave_9keV')

    # need to grab average 21fast and all gadget realizations
    ave_r1_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_mh_cdm', 'gadget_r1_cdm')
    ave_r2_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_mh_cdm', 'gadget_r2_cdm')
    ave_r3_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_mh_cdm', 'gadget_r3_cdm')
    ave_r4_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_mh_cdm', 'gadget_r4_cdm')

    ave_r1_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cm_avg_mh_wdm3', 'gadget_r1_3keV')
    ave_r2_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cm_avg_mh_wdm3', 'gadget_r2_3keV')
    ave_r3_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cm_avg_mh_wdm3', 'gadget_r3_3keV')
    ave_r4_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cm_avg_mh_wdm3', 'gadget_r4_3keV')

    ave_r1_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cm_avg_mh_wdm4', 'gadget_r1_4keV')
    ave_r2_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cm_avg_mh_wdm4', 'gadget_r2_4keV')
    ave_r3_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cm_avg_mh_wdm4', 'gadget_r3_4keV')
    ave_r4_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cm_avg_mh_wdm4', 'gadget_r4_4keV')

    ave_r1_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cm_avg_mh_wdm6', 'gadget_r1_6keV')
    ave_r2_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cm_avg_mh_wdm6', 'gadget_r2_6keV')
    ave_r3_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cm_avg_mh_wdm6', 'gadget_r3_6keV')
    ave_r4_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cm_avg_mh_wdm6', 'gadget_r4_6keV')

    ave_r1_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cm_avg_mh_wdm9', 'gadget_r1_9keV')
    ave_r2_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cm_avg_mh_wdm9', 'gadget_r2_9keV')
    ave_r3_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cm_avg_mh_wdm9', 'gadget_r3_9keV')
    ave_r4_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cm_avg_mh_wdm9', 'gadget_r4_9keV')

    # need to grab the overall mean of both, which gives us our true mean value
    ave_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_mh_cdm', 'gadget_ave_cdm')
    ave_ave_3keV = th_y_mh.theory_P_lyas(3.0, 0.8159, '21cm_avg_mh_wdm3', 'gadget_ave_3keV')
    ave_ave_4keV = th_y_mh.theory_P_lyas(4.0, 0.8159, '21cm_avg_mh_wdm4', 'gadget_ave_4keV')
    ave_ave_6keV = th_y_mh.theory_P_lyas(6.0, 0.8159, '21cm_avg_mh_wdm6', 'gadget_ave_6keV')
    ave_ave_9keV = th_y_mh.theory_P_lyas(9.0, 0.8159, '21cm_avg_mh_wdm9', 'gadget_ave_9keV')
    
    # need the fiducial for comparison so 
    fid_r1_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_nmh_r1', 'gadget_ave_cdm')
    fid_r2_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_nmh_r2', 'gadget_ave_cdm')
    fid_r3_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_nmh_r3', 'gadget_ave_cdm')
    fid_r4_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_nmh_r4', 'gadget_ave_cdm')
    
    fid_ave_r1_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_nmh_cdm', 'gadget_r1_cdm')
    fid_ave_r2_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_nmh_cdm', 'gadget_r2_cdm')
    fid_ave_r3_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_nmh_cdm', 'gadget_r3_cdm')
    fid_ave_r4_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_nmh_cdm', 'gadget_r4_cdm')
    
    fid_ave_ave_cdm = th_y_mh.theory_P_lyas(np.infty, 0.8159, '21cmfast_avg_nmh_cdm', 'gadget_ave_cdm')
    
else:
    # nomenclature to deal with this procedure model_21cmrealization_gadgetrealization, e.g. 
    # r1_ave_3keV uses gadget mean.

    # need to do average Gadget and all the 21cm fast realizations
    r1_ave_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_r1_cdm', 'gadget_ave_cdm')
    r2_ave_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_r2_cdm', 'gadget_ave_cdm')
    r3_ave_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_r3_cdm', 'gadget_ave_cdm')
    r4_ave_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_r4_cdm', 'gadget_ave_cdm')

    r1_ave_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_r1_wdm3', 'gadget_ave_3keV')
    r2_ave_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_r2_wdm3', 'gadget_ave_3keV')
    r3_ave_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_r3_wdm3', 'gadget_ave_3keV')
    r4_ave_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_r4_wdm3', 'gadget_ave_3keV')

    r1_ave_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_r1_wdm4', 'gadget_ave_4keV')
    r2_ave_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_r2_wdm4', 'gadget_ave_4keV')
    r3_ave_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_r3_wdm4', 'gadget_ave_4keV')
    r4_ave_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_r4_wdm4', 'gadget_ave_4keV')

    r1_ave_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_r1_wdm6', 'gadget_ave_6keV')
    r2_ave_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_r2_wdm6', 'gadget_ave_6keV')
    r3_ave_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_r3_wdm6', 'gadget_ave_6keV')
    r4_ave_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_r4_wdm6', 'gadget_ave_6keV')

    r1_ave_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_r1_wdm9', 'gadget_ave_9keV')
    r2_ave_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_r2_wdm9', 'gadget_ave_9keV')
    r3_ave_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_r3_wdm9', 'gadget_ave_9keV')
    r4_ave_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_r4_wdm9', 'gadget_ave_9keV')

    # need to grab average 21fast and all gadget realizations
    ave_r1_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_avg_cdm', 'gadget_r1_cdm')
    ave_r2_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_avg_cdm', 'gadget_r2_cdm')
    ave_r3_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_avg_cdm', 'gadget_r3_cdm')
    ave_r4_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_avg_cdm', 'gadget_r4_cdm')

    ave_r1_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_avg_wdm3', 'gadget_r1_3keV')
    ave_r2_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_avg_wdm3', 'gadget_r2_3keV')
    ave_r3_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_avg_wdm3', 'gadget_r3_3keV')
    ave_r4_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_avg_wdm3', 'gadget_r4_3keV')

    ave_r1_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_avg_wdm4', 'gadget_r1_4keV')
    ave_r2_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_avg_wdm4', 'gadget_r2_4keV')
    ave_r3_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_avg_wdm4', 'gadget_r3_4keV')
    ave_r4_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_avg_wdm4', 'gadget_r4_4keV')

    ave_r1_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_avg_wdm6', 'gadget_r1_6keV')
    ave_r2_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_avg_wdm6', 'gadget_r2_6keV')
    ave_r3_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_avg_wdm6', 'gadget_r3_6keV')
    ave_r4_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_avg_wdm6', 'gadget_r4_6keV')

    ave_r1_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_avg_wdm9', 'gadget_r1_9keV')
    ave_r2_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_avg_wdm9', 'gadget_r2_9keV')
    ave_r3_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_avg_wdm9', 'gadget_r3_9keV')
    ave_r4_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_avg_wdm9', 'gadget_r4_9keV')

    # need to grab the overall mean of both, which gives us our true mean value
    ave_ave_cdm = th_y.theory_P_lyas(np.infty, 0.8159, '21cm_avg_cdm', 'gadget_ave_cdm')
    ave_ave_3keV = th_y.theory_P_lyas(3.0, 0.8159, '21cm_avg_wdm3', 'gadget_ave_3keV')
    ave_ave_4keV = th_y.theory_P_lyas(4.0, 0.8159, '21cm_avg_wdm4', 'gadget_ave_4keV')
    ave_ave_6keV = th_y.theory_P_lyas(6.0, 0.8159, '21cm_avg_wdm6', 'gadget_ave_6keV')
    ave_ave_9keV = th_y.theory_P_lyas(9.0, 0.8159, '21cm_avg_wdm9', 'gadget_ave_9keV')
# Out:
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# Finished prepping the model for P_m
# ...

# %%
def sample_variance(ave_ave, r1_ave, r2_ave, r3_ave, r4_ave, ave_r1, ave_r2, ave_r3, ave_r4):
    # computes the sample variance on the mean, i.e. our errorbar, for a given quantity of interest.
    # example input would be power spectra for all those realizations
    # error due to 21cmFAST simulations
    error_fast = (r1_ave - ave_ave)**2 + (r2_ave - ave_ave)**2 + (r3_ave - ave_ave)**2 + (r4_ave - ave_ave)**2
    error_fast = np.sqrt(error_fast / 4.)
    # error due to gadget sims
    error_gadget = (ave_r1 - ave_ave)**2 + (ave_r2 - ave_ave)**2 + (ave_r3 - ave_ave)**2 + (ave_r4 - ave_ave)**2
    error_gadget = np.sqrt(error_gadget / 4.)
    # add in quadrature, i.e. assumme that both simulations are totally uncorrelated (as they should!)
    total_error = np.sqrt(error_gadget**2 + error_fast**2)
    return total_error

# %%
def frac_diff(cdm, wdm):
    # computes the fractional difference of wdm model vs cdm 
    return 100. * np.abs(wdm - cdm) / cdm

# %%
# play around at two different redshifts, and for close to line-of-sight.
# I think it is better to plot total flux power spectrum and then fractional difference
# k_array = np.linspace(0.06, 1.4, 500)
k_array = ave_ave_cdm.k_21cm
z1 = 2.0 # redshift of observation
# average 
ave_ave_cdm_plot_z1 = np.zeros(len(k_array))
ave_ave_3keV_plot_z1 = np.zeros(len(k_array))
ave_ave_4keV_plot_z1 = np.zeros(len(k_array))
ave_ave_6keV_plot_z1 = np.zeros(len(k_array))
ave_ave_9keV_plot_z1 = np.zeros(len(k_array))

# dummy for error
ave_ave_cdm_error_z1 = np.zeros(len(k_array))
ave_ave_3keV_error_z1 = np.zeros(len(k_array))
ave_ave_4keV_error_z1 = np.zeros(len(k_array))
ave_ave_6keV_error_z1 = np.zeros(len(k_array))
ave_ave_9keV_error_z1 = np.zeros(len(k_array))

if mini_halos == True:
    fid_ave_ave_cdm_plot_z1 = np.zeros(len(k_array))
    fid_ave_ave_cdm_error_z1 = np.zeros(len(k_array))
    
    fid_r1_ave_cdm_plot_z1 = np.zeros(len(k_array))
    fid_r2_ave_cdm_plot_z1 = np.zeros(len(k_array))
    fid_r3_ave_cdm_plot_z1 = np.zeros(len(k_array))
    fid_r4_ave_cdm_plot_z1 = np.zeros(len(k_array))
    
    fid_ave_r1_cdm_plot_z1 = np.zeros(len(k_array))
    fid_ave_r2_cdm_plot_z1 = np.zeros(len(k_array))
    fid_ave_r3_cdm_plot_z1 = np.zeros(len(k_array))
    fid_ave_r4_cdm_plot_z1 = np.zeros(len(k_array))
    
    fid_ave_ave_cdm_plot_z5 = np.zeros(len(k_array))
    fid_ave_ave_cdm_error_z5 = np.zeros(len(k_array))
    
    fid_r1_ave_cdm_plot_z5 = np.zeros(len(k_array))
    fid_r2_ave_cdm_plot_z5 = np.zeros(len(k_array))
    fid_r3_ave_cdm_plot_z5 = np.zeros(len(k_array))
    fid_r4_ave_cdm_plot_z5 = np.zeros(len(k_array))
    
    fid_ave_r1_cdm_plot_z5 = np.zeros(len(k_array))
    fid_ave_r2_cdm_plot_z5 = np.zeros(len(k_array))
    fid_ave_r3_cdm_plot_z5 = np.zeros(len(k_array))
    fid_ave_r4_cdm_plot_z5 = np.zeros(len(k_array))

# 21cmfast realizations
r1_ave_cdm_plot_z1 = np.zeros(len(k_array))
r1_ave_3keV_plot_z1 = np.zeros(len(k_array))
r1_ave_4keV_plot_z1 = np.zeros(len(k_array))
r1_ave_6keV_plot_z1 = np.zeros(len(k_array))
r1_ave_9keV_plot_z1 = np.zeros(len(k_array))

r2_ave_cdm_plot_z1 = np.zeros(len(k_array))
r2_ave_3keV_plot_z1 = np.zeros(len(k_array))
r2_ave_4keV_plot_z1 = np.zeros(len(k_array))
r2_ave_6keV_plot_z1 = np.zeros(len(k_array))
r2_ave_9keV_plot_z1 = np.zeros(len(k_array))

r3_ave_cdm_plot_z1 = np.zeros(len(k_array))
r3_ave_3keV_plot_z1 = np.zeros(len(k_array))
r3_ave_4keV_plot_z1 = np.zeros(len(k_array))
r3_ave_6keV_plot_z1 = np.zeros(len(k_array))
r3_ave_9keV_plot_z1 = np.zeros(len(k_array))

r4_ave_cdm_plot_z1 = np.zeros(len(k_array))
r4_ave_3keV_plot_z1 = np.zeros(len(k_array))
r4_ave_4keV_plot_z1 = np.zeros(len(k_array))
r4_ave_6keV_plot_z1 = np.zeros(len(k_array))
r4_ave_9keV_plot_z1 = np.zeros(len(k_array))

# gadget realizations
ave_r1_cdm_plot_z1 = np.zeros(len(k_array))
ave_r1_3keV_plot_z1 = np.zeros(len(k_array))
ave_r1_4keV_plot_z1 = np.zeros(len(k_array))
ave_r1_6keV_plot_z1 = np.zeros(len(k_array))
ave_r1_9keV_plot_z1 = np.zeros(len(k_array))

ave_r2_cdm_plot_z1 = np.zeros(len(k_array))
ave_r2_3keV_plot_z1 = np.zeros(len(k_array))
ave_r2_4keV_plot_z1 = np.zeros(len(k_array))
ave_r2_6keV_plot_z1 = np.zeros(len(k_array))
ave_r2_9keV_plot_z1 = np.zeros(len(k_array))

ave_r3_cdm_plot_z1 = np.zeros(len(k_array))
ave_r3_3keV_plot_z1 = np.zeros(len(k_array))
ave_r3_4keV_plot_z1 = np.zeros(len(k_array))
ave_r3_6keV_plot_z1 = np.zeros(len(k_array))
ave_r3_9keV_plot_z1 = np.zeros(len(k_array))

ave_r4_cdm_plot_z1 = np.zeros(len(k_array))
ave_r4_3keV_plot_z1 = np.zeros(len(k_array))
ave_r4_4keV_plot_z1 = np.zeros(len(k_array))
ave_r4_6keV_plot_z1 = np.zeros(len(k_array))
ave_r4_9keV_plot_z1 = np.zeros(len(k_array))

# next redshift
z5 = 4.0 # redshift of observation
ave_ave_cdm_plot_z5 = np.zeros(len(k_array))
ave_ave_3keV_plot_z5 = np.zeros(len(k_array))
ave_ave_4keV_plot_z5 = np.zeros(len(k_array))
ave_ave_6keV_plot_z5 = np.zeros(len(k_array))
ave_ave_9keV_plot_z5 = np.zeros(len(k_array))

# dummy for error
ave_ave_cdm_error_z5 = np.zeros(len(k_array))
ave_ave_3keV_error_z5 = np.zeros(len(k_array))
ave_ave_4keV_error_z5 = np.zeros(len(k_array))
ave_ave_6keV_error_z5 = np.zeros(len(k_array))
ave_ave_9keV_error_z5 = np.zeros(len(k_array))

# 21cmfast realizations
r1_ave_cdm_plot_z5 = np.zeros(len(k_array))
r1_ave_3keV_plot_z5 = np.zeros(len(k_array))
r1_ave_4keV_plot_z5 = np.zeros(len(k_array))
r1_ave_6keV_plot_z5 = np.zeros(len(k_array))
r1_ave_9keV_plot_z5 = np.zeros(len(k_array))

r2_ave_cdm_plot_z5 = np.zeros(len(k_array))
r2_ave_3keV_plot_z5 = np.zeros(len(k_array))
r2_ave_4keV_plot_z5 = np.zeros(len(k_array))
r2_ave_6keV_plot_z5 = np.zeros(len(k_array))
r2_ave_9keV_plot_z5 = np.zeros(len(k_array))

r3_ave_cdm_plot_z5 = np.zeros(len(k_array))
r3_ave_3keV_plot_z5 = np.zeros(len(k_array))
r3_ave_4keV_plot_z5 = np.zeros(len(k_array))
r3_ave_6keV_plot_z5 = np.zeros(len(k_array))
r3_ave_9keV_plot_z5 = np.zeros(len(k_array))

r4_ave_cdm_plot_z5 = np.zeros(len(k_array))
r4_ave_3keV_plot_z5 = np.zeros(len(k_array))
r4_ave_4keV_plot_z5 = np.zeros(len(k_array))
r4_ave_6keV_plot_z5 = np.zeros(len(k_array))
r4_ave_9keV_plot_z5 = np.zeros(len(k_array))

# gadget realizations
ave_r1_cdm_plot_z5 = np.zeros(len(k_array))
ave_r1_3keV_plot_z5 = np.zeros(len(k_array))
ave_r1_4keV_plot_z5 = np.zeros(len(k_array))
ave_r1_6keV_plot_z5 = np.zeros(len(k_array))
ave_r1_9keV_plot_z5 = np.zeros(len(k_array))

ave_r2_cdm_plot_z5 = np.zeros(len(k_array))
ave_r2_3keV_plot_z5 = np.zeros(len(k_array))
ave_r2_4keV_plot_z5 = np.zeros(len(k_array))
ave_r2_6keV_plot_z5 = np.zeros(len(k_array))
ave_r2_9keV_plot_z5 = np.zeros(len(k_array))

ave_r3_cdm_plot_z5 = np.zeros(len(k_array))
ave_r3_3keV_plot_z5 = np.zeros(len(k_array))
ave_r3_4keV_plot_z5 = np.zeros(len(k_array))
ave_r3_6keV_plot_z5 = np.zeros(len(k_array))
ave_r3_9keV_plot_z5 = np.zeros(len(k_array))

ave_r4_cdm_plot_z5 = np.zeros(len(k_array))
ave_r4_3keV_plot_z5 = np.zeros(len(k_array))
ave_r4_4keV_plot_z5 = np.zeros(len(k_array))
ave_r4_6keV_plot_z5 = np.zeros(len(k_array))
ave_r4_9keV_plot_z5 = np.zeros(len(k_array))

for i in range(0,len(k_array)):
    # frist redshift
    # average
    ave_ave_cdm_plot_z1[i] = ave_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_ave_3keV_plot_z1[i] = ave_ave_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_ave_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_ave_4keV_plot_z1[i] = ave_ave_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_ave_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_ave_6keV_plot_z1[i] = ave_ave_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_ave_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_ave_9keV_plot_z1[i] = ave_ave_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_ave_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    # 21cmfast realizations
    r1_ave_cdm_plot_z1[i] = r1_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r1_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r1_ave_3keV_plot_z1[i] = r1_ave_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r1_ave_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r1_ave_4keV_plot_z1[i] = r1_ave_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r1_ave_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r1_ave_6keV_plot_z1[i] = r1_ave_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r1_ave_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r1_ave_9keV_plot_z1[i] = r1_ave_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r1_ave_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    
    r2_ave_cdm_plot_z1[i] = r2_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r2_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r2_ave_3keV_plot_z1[i] = r2_ave_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r2_ave_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r2_ave_4keV_plot_z1[i] = r2_ave_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r2_ave_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r2_ave_6keV_plot_z1[i] = r2_ave_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r2_ave_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r2_ave_9keV_plot_z1[i] = r2_ave_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r2_ave_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    
    r3_ave_cdm_plot_z1[i] = r3_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r3_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r3_ave_3keV_plot_z1[i] = r3_ave_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r3_ave_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r3_ave_4keV_plot_z1[i] = r3_ave_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r3_ave_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r3_ave_6keV_plot_z1[i] = r3_ave_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r3_ave_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r3_ave_9keV_plot_z1[i] = r3_ave_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r3_ave_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)

    r4_ave_cdm_plot_z1[i] = r4_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r4_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r4_ave_3keV_plot_z1[i] = r4_ave_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r4_ave_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r4_ave_4keV_plot_z1[i] = r4_ave_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r4_ave_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r4_ave_6keV_plot_z1[i] = r4_ave_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r4_ave_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    r4_ave_9keV_plot_z1[i] = r4_ave_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + r4_ave_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    # gadget realizations
    ave_r1_cdm_plot_z1[i] = ave_r1_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r1_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r1_3keV_plot_z1[i] = ave_r1_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r1_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r1_4keV_plot_z1[i] = ave_r1_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r1_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r1_6keV_plot_z1[i] = ave_r1_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r1_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r1_9keV_plot_z1[i] = ave_r1_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r1_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)

    ave_r2_cdm_plot_z1[i] = ave_r2_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r2_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r2_3keV_plot_z1[i] = ave_r2_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r2_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r2_4keV_plot_z1[i] = ave_r2_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r2_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r2_6keV_plot_z1[i] = ave_r2_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r2_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r2_9keV_plot_z1[i] = ave_r2_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r2_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)

    ave_r3_cdm_plot_z1[i] = ave_r3_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r3_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r3_3keV_plot_z1[i] = ave_r3_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r3_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r3_4keV_plot_z1[i] = ave_r3_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r3_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r3_6keV_plot_z1[i] = ave_r3_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r3_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r3_9keV_plot_z1[i] = ave_r3_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r3_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)

    ave_r4_cdm_plot_z1[i] = ave_r4_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r4_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r4_3keV_plot_z1[i] = ave_r4_3keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r4_3keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r4_4keV_plot_z1[i] = ave_r4_4keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r4_4keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r4_6keV_plot_z1[i] = ave_r4_6keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r4_6keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    ave_r4_9keV_plot_z1[i] = ave_r4_9keV.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + ave_r4_9keV.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
    # next redshift
    # average
    ave_ave_cdm_plot_z5[i] = ave_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_ave_3keV_plot_z5[i] = ave_ave_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_ave_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_ave_4keV_plot_z5[i] = ave_ave_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_ave_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_ave_6keV_plot_z5[i] = ave_ave_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_ave_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_ave_9keV_plot_z5[i] = ave_ave_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_ave_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    # 21cmfast realizations
    r1_ave_cdm_plot_z5[i] = r1_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r1_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r1_ave_3keV_plot_z5[i] = r1_ave_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r1_ave_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r1_ave_4keV_plot_z5[i] = r1_ave_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r1_ave_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r1_ave_6keV_plot_z5[i] = r1_ave_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r1_ave_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r1_ave_9keV_plot_z5[i] = r1_ave_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r1_ave_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    
    r2_ave_cdm_plot_z5[i] = r2_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r2_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r2_ave_3keV_plot_z5[i] = r2_ave_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r2_ave_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r2_ave_4keV_plot_z5[i] = r2_ave_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r2_ave_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r2_ave_6keV_plot_z5[i] = r2_ave_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r2_ave_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r2_ave_9keV_plot_z5[i] = r2_ave_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r2_ave_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    
    r3_ave_cdm_plot_z5[i] = r3_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r3_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r3_ave_3keV_plot_z5[i] = r3_ave_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r3_ave_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r3_ave_4keV_plot_z5[i] = r3_ave_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r3_ave_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r3_ave_6keV_plot_z5[i] = r3_ave_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r3_ave_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r3_ave_9keV_plot_z5[i] = r3_ave_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r3_ave_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)

    r4_ave_cdm_plot_z5[i] = r4_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r4_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r4_ave_3keV_plot_z5[i] = r4_ave_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r4_ave_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r4_ave_4keV_plot_z5[i] = r4_ave_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r4_ave_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r4_ave_6keV_plot_z5[i] = r4_ave_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r4_ave_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    r4_ave_9keV_plot_z5[i] = r4_ave_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + r4_ave_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    # gadget realizations
    ave_r1_cdm_plot_z5[i] = ave_r1_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r1_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r1_3keV_plot_z5[i] = ave_r1_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r1_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r1_4keV_plot_z5[i] = ave_r1_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r1_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r1_6keV_plot_z5[i] = ave_r1_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r1_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r1_9keV_plot_z5[i] = ave_r1_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r1_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)

    ave_r2_cdm_plot_z5[i] = ave_r2_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r2_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r2_3keV_plot_z5[i] = ave_r2_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r2_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r2_4keV_plot_z5[i] = ave_r2_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r2_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r2_6keV_plot_z5[i] = ave_r2_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r2_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r2_9keV_plot_z5[i] = ave_r2_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r2_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)

    ave_r3_cdm_plot_z5[i] = ave_r3_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r3_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r3_3keV_plot_z5[i] = ave_r3_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r3_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r3_4keV_plot_z5[i] = ave_r3_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r3_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r3_6keV_plot_z5[i] = ave_r3_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r3_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r3_9keV_plot_z5[i] = ave_r3_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r3_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)

    ave_r4_cdm_plot_z5[i] = ave_r4_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r4_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r4_3keV_plot_z5[i] = ave_r4_3keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r4_3keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r4_4keV_plot_z5[i] = ave_r4_4keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r4_4keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r4_6keV_plot_z5[i] = ave_r4_6keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r4_6keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    ave_r4_9keV_plot_z5[i] = ave_r4_9keV.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + ave_r4_9keV.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
    
    if mini_halos == True:
        fid_ave_ave_cdm_plot_z1[i] = fid_ave_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_ave_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        
        fid_r1_ave_cdm_plot_z1[i] = fid_r1_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_r1_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_r2_ave_cdm_plot_z1[i] = fid_r2_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_r2_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_r3_ave_cdm_plot_z1[i] = fid_r3_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_r3_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_r4_ave_cdm_plot_z1[i] = fid_r4_ave_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_r4_ave_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        
        fid_ave_r1_cdm_plot_z1[i] = fid_ave_r1_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_ave_r1_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_ave_r2_cdm_plot_z1[i] = fid_ave_r2_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_ave_r2_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_ave_r3_cdm_plot_z1[i] = fid_ave_r3_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_ave_r3_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        fid_ave_r4_cdm_plot_z1[i] = fid_ave_r4_cdm.FluxP3D_lya_Mpc(z1, k_array[i], 0.1) + fid_ave_r4_cdm.FluxP3D_reio_Mpc(z1, k_array[i], 0.1)
        
        fid_ave_ave_cdm_plot_z5[i] = fid_ave_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_ave_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        
        fid_r1_ave_cdm_plot_z5[i] = fid_r1_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_r1_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_r2_ave_cdm_plot_z5[i] = fid_r2_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_r2_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_r3_ave_cdm_plot_z5[i] = fid_r3_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_r3_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_r4_ave_cdm_plot_z5[i] = fid_r4_ave_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_r4_ave_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        
        fid_ave_r1_cdm_plot_z5[i] = fid_ave_r1_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_ave_r1_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_ave_r2_cdm_plot_z5[i] = fid_ave_r2_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_ave_r2_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_ave_r3_cdm_plot_z5[i] = fid_ave_r3_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_ave_r3_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)
        fid_ave_r4_cdm_plot_z5[i] = fid_ave_r4_cdm.FluxP3D_lya_Mpc(z5, k_array[i], 0.1) + fid_ave_r4_cdm.FluxP3D_reio_Mpc(z5, k_array[i], 0.1)

# %%
print(ave_ave_cdm.FluxP3D_lya_Mpc(z5, 0.1, 0.1), ave_ave_cdm.FluxP3D_reio_Mpc(z5, 0.1, 0.1))
# Out:
# [71.23835362] [104.48061235]

# %%
#print(fid_ave_ave_cdm_plot_z5)

# %%
# now we have all the data, so we can actually compute the errorbar
ave_ave_cdm_error_z1 = sample_variance(ave_ave_cdm_plot_z1, r1_ave_cdm_plot_z1, r2_ave_cdm_plot_z1, r3_ave_cdm_plot_z1, r4_ave_cdm_plot_z1, ave_r1_cdm_plot_z1, ave_r2_cdm_plot_z1, ave_r3_cdm_plot_z1, ave_r4_cdm_plot_z1)
ave_ave_3keV_error_z1 = sample_variance(ave_ave_3keV_plot_z1, r1_ave_3keV_plot_z1, r2_ave_3keV_plot_z1, r3_ave_3keV_plot_z1, r4_ave_3keV_plot_z1, ave_r1_3keV_plot_z1, ave_r2_3keV_plot_z1, ave_r3_3keV_plot_z1, ave_r4_3keV_plot_z1)
ave_ave_4keV_error_z1 = sample_variance(ave_ave_4keV_plot_z1, r1_ave_4keV_plot_z1, r2_ave_4keV_plot_z1, r3_ave_4keV_plot_z1, r4_ave_4keV_plot_z1, ave_r1_4keV_plot_z1, ave_r2_4keV_plot_z1, ave_r3_4keV_plot_z1, ave_r4_4keV_plot_z1)
ave_ave_6keV_error_z1 = sample_variance(ave_ave_6keV_plot_z1, r1_ave_6keV_plot_z1, r2_ave_6keV_plot_z1, r3_ave_6keV_plot_z1, r4_ave_6keV_plot_z1, ave_r1_6keV_plot_z1, ave_r2_6keV_plot_z1, ave_r3_6keV_plot_z1, ave_r4_6keV_plot_z1)
ave_ave_9keV_error_z1 = sample_variance(ave_ave_9keV_plot_z1, r1_ave_9keV_plot_z1, r2_ave_9keV_plot_z1, r3_ave_9keV_plot_z1, r4_ave_9keV_plot_z1, ave_r1_9keV_plot_z1, ave_r2_9keV_plot_z1, ave_r3_9keV_plot_z1, ave_r4_9keV_plot_z1)
# we need the other redshift too
ave_ave_cdm_error_z5 = sample_variance(ave_ave_cdm_plot_z5, r1_ave_cdm_plot_z5, r2_ave_cdm_plot_z5, r3_ave_cdm_plot_z5, r4_ave_cdm_plot_z5, ave_r1_cdm_plot_z5, ave_r2_cdm_plot_z5, ave_r3_cdm_plot_z5, ave_r4_cdm_plot_z5)
ave_ave_3keV_error_z5 = sample_variance(ave_ave_3keV_plot_z5, r1_ave_3keV_plot_z5, r2_ave_3keV_plot_z5, r3_ave_3keV_plot_z5, r4_ave_3keV_plot_z5, ave_r1_3keV_plot_z5, ave_r2_3keV_plot_z5, ave_r3_3keV_plot_z5, ave_r4_3keV_plot_z5)
ave_ave_4keV_error_z5 = sample_variance(ave_ave_4keV_plot_z5, r1_ave_4keV_plot_z5, r2_ave_4keV_plot_z5, r3_ave_4keV_plot_z5, r4_ave_4keV_plot_z5, ave_r1_4keV_plot_z5, ave_r2_4keV_plot_z5, ave_r3_4keV_plot_z5, ave_r4_4keV_plot_z5)
ave_ave_6keV_error_z5 = sample_variance(ave_ave_6keV_plot_z5, r1_ave_6keV_plot_z5, r2_ave_6keV_plot_z5, r3_ave_6keV_plot_z5, r4_ave_6keV_plot_z5, ave_r1_6keV_plot_z5, ave_r2_6keV_plot_z5, ave_r3_6keV_plot_z5, ave_r4_6keV_plot_z5)
ave_ave_9keV_error_z5 = sample_variance(ave_ave_9keV_plot_z5, r1_ave_9keV_plot_z5, r2_ave_9keV_plot_z5, r3_ave_9keV_plot_z5, r4_ave_9keV_plot_z5, ave_r1_9keV_plot_z5, ave_r2_9keV_plot_z5, ave_r3_9keV_plot_z5, ave_r4_9keV_plot_z5)

if mini_halos == True:
    fid_ave_ave_cdm_error_z1 = sample_variance(fid_ave_ave_cdm_plot_z1, fid_r1_ave_cdm_plot_z1, fid_r2_ave_cdm_plot_z1, fid_r3_ave_cdm_plot_z1, fid_r4_ave_cdm_plot_z1, fid_ave_r1_cdm_plot_z1, fid_ave_r2_cdm_plot_z1, fid_ave_r3_cdm_plot_z1, fid_ave_r4_cdm_plot_z1)
    fid_ave_ave_cdm_error_z5 = sample_variance(fid_ave_ave_cdm_plot_z5, fid_r1_ave_cdm_plot_z5, fid_r2_ave_cdm_plot_z5, fid_r3_ave_cdm_plot_z5, fid_r4_ave_cdm_plot_z5, fid_ave_r1_cdm_plot_z5, fid_ave_r2_cdm_plot_z5, fid_ave_r3_cdm_plot_z5, fid_ave_r4_cdm_plot_z5)
    # now if we want to do fractional difference let's use what we have done
    # first the "mean" one
#     dif_ave_ave_cdm_z1  = frac_diff(fid_ave_ave_cdm_plot_z1, ave_ave_cdm_plot_z1)
    dif_ave_ave_3keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_3keV_plot_z1)
    dif_ave_ave_4keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_4keV_plot_z1)
    dif_ave_ave_6keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_6keV_plot_z1)
    dif_ave_ave_9keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_9keV_plot_z1)
#     dif_ave_ave_3keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_3keV_plot_z1)
#     dif_ave_ave_4keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_4keV_plot_z1)
#     dif_ave_ave_6keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_6keV_plot_z1)
#     dif_ave_ave_9keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_9keV_plot_z1)
    # now the realizations, starting with 21cmFAST 
#     dif_r1_ave_cdm_z1  = frac_diff(fid_r1_ave_cdm_plot_z1, r1_ave_cdm_plot_z1)
    dif_r1_ave_3keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_3keV_plot_z1)
    dif_r1_ave_4keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_4keV_plot_z1)
    dif_r1_ave_6keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_6keV_plot_z1)
    dif_r1_ave_9keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_9keV_plot_z1)

#     dif_r2_ave_cdm_z1  = frac_diff(fid_r2_ave_cdm_plot_z1, r2_ave_cdm_plot_z1)
    dif_r2_ave_3keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_3keV_plot_z1)
    dif_r2_ave_4keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_4keV_plot_z1)
    dif_r2_ave_6keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_6keV_plot_z1)
    dif_r2_ave_9keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_9keV_plot_z1)

#     dif_r3_ave_cdm_z1  = frac_diff(fid_r3_ave_cdm_plot_z1, r3_ave_cdm_plot_z1)
    dif_r3_ave_3keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_3keV_plot_z1)
    dif_r3_ave_4keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_4keV_plot_z1)
    dif_r3_ave_6keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_6keV_plot_z1)
    dif_r3_ave_9keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_9keV_plot_z1)

#     dif_r4_ave_cdm_z1  = frac_diff(fid_r4_ave_cdm_plot_z1, r4_ave_cdm_plot_z1)
    dif_r4_ave_3keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_3keV_plot_z1)
    dif_r4_ave_4keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_4keV_plot_z1)
    dif_r4_ave_6keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_6keV_plot_z1)
    dif_r4_ave_9keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_9keV_plot_z1)
    # now gadget realizations
#     dif_ave_r1_cdm_z1  = frac_diff(fid_ave_r1_cdm_plot_z1, ave_r1_cdm_plot_z1)
    dif_ave_r1_3keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_3keV_plot_z1)
    dif_ave_r1_4keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_4keV_plot_z1)
    dif_ave_r1_6keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_6keV_plot_z1)
    dif_ave_r1_9keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_9keV_plot_z1)

#     dif_ave_r2_cdm_z1  = frac_diff(fid_ave_r2_cdm_plot_z1, ave_r2_cdm_plot_z1)
    dif_ave_r2_3keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_3keV_plot_z1)
    dif_ave_r2_4keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_4keV_plot_z1)
    dif_ave_r2_6keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_6keV_plot_z1)
    dif_ave_r2_9keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_9keV_plot_z1)

#     dif_ave_r3_cdm_z1  = frac_diff(fid_ave_r3_cdm_plot_z1, ave_r3_cdm_plot_z1)
    dif_ave_r3_3keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_3keV_plot_z1)
    dif_ave_r3_4keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_4keV_plot_z1)
    dif_ave_r3_6keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_6keV_plot_z1)
    dif_ave_r3_9keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_9keV_plot_z1)

#     dif_ave_r4_cdm_z1  = frac_diff(fid_ave_r4_cdm_plot_z1, ave_r4_cdm_plot_z1)
    dif_ave_r4_3keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_3keV_plot_z1)
    dif_ave_r4_4keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_4keV_plot_z1)
    dif_ave_r4_6keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_6keV_plot_z1)
    dif_ave_r4_9keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_9keV_plot_z1)
    # and the next redshift
    # first the "mean" one
#     dif_ave_ave_cdm_z5  = frac_diff(fid_ave_ave_cdm_plot_z5, ave_ave_cdm_plot_z5)
    dif_ave_ave_3keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_3keV_plot_z5)
    dif_ave_ave_4keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_4keV_plot_z5)
    dif_ave_ave_6keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_6keV_plot_z5)
    dif_ave_ave_9keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_9keV_plot_z5)
    # now the realizations, starting with 21cmFAST 
#     dif_r1_ave_cdm_z5  = frac_diff(fid_r1_ave_cdm_plot_z5, r1_ave_cdm_plot_z5)
    dif_r1_ave_3keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_3keV_plot_z5)
    dif_r1_ave_4keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_4keV_plot_z5)
    dif_r1_ave_6keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_6keV_plot_z5)
    dif_r1_ave_9keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_9keV_plot_z5)

#     dif_r2_ave_cdm_z5  = frac_diff(fid_r2_ave_cdm_plot_z5, r2_ave_cdm_plot_z5)
    dif_r2_ave_3keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_3keV_plot_z5)
    dif_r2_ave_4keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_4keV_plot_z5)
    dif_r2_ave_6keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_6keV_plot_z5)
    dif_r2_ave_9keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_9keV_plot_z5)

#     dif_r3_ave_cdm_z5  = frac_diff(fid_r3_ave_cdm_plot_z5, r3_ave_cdm_plot_z5)
    dif_r3_ave_3keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_3keV_plot_z5)
    dif_r3_ave_4keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_4keV_plot_z5)
    dif_r3_ave_6keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_6keV_plot_z5)
    dif_r3_ave_9keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_9keV_plot_z5)

#     dif_r4_ave_cdm_z5  = frac_diff(fid_r4_ave_cdm_plot_z5, r4_ave_cdm_plot_z5)
    dif_r4_ave_3keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_3keV_plot_z5)
    dif_r4_ave_4keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_4keV_plot_z5)
    dif_r4_ave_6keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_6keV_plot_z5)
    dif_r4_ave_9keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_9keV_plot_z5)
    # now gadget realizations
#     dif_ave_r1_cdm_z5  = frac_diff(fid_ave_r1_cdm_plot_z5, ave_r1_cdm_plot_z5)
    dif_ave_r1_3keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_3keV_plot_z5)
    dif_ave_r1_4keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_4keV_plot_z5)
    dif_ave_r1_6keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_6keV_plot_z5)
    dif_ave_r1_9keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_9keV_plot_z5)

#     dif_ave_r2_cdm_z5  = frac_diff(fid_ave_r2_cdm_plot_z5, ave_r2_cdm_plot_z5)
    dif_ave_r2_3keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_3keV_plot_z5)
    dif_ave_r2_4keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_4keV_plot_z5)
    dif_ave_r2_6keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_6keV_plot_z5)
    dif_ave_r2_9keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_9keV_plot_z5)

#     dif_ave_r3_cdm_z5  = frac_diff(fid_ave_r3_cdm_plot_z5, ave_r3_cdm_plot_z5)
    dif_ave_r3_3keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_3keV_plot_z5)
    dif_ave_r3_4keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_4keV_plot_z5)
    dif_ave_r3_6keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_6keV_plot_z5)
    dif_ave_r3_9keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_9keV_plot_z5)

#     dif_ave_r4_cdm_z5  = frac_diff(fid_ave_r4_cdm_plot_z5, ave_r4_cdm_plot_z5)
    dif_ave_r4_3keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_3keV_plot_z5)
    dif_ave_r4_4keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_4keV_plot_z5)
    dif_ave_r4_6keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_6keV_plot_z5)
    dif_ave_r4_9keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_9keV_plot_z5)

else:
    # now if we want to do fractional difference let's use what we have done
    # first the "mean" one
    dif_ave_ave_3keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_3keV_plot_z1)
    dif_ave_ave_4keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_4keV_plot_z1)
    dif_ave_ave_6keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_6keV_plot_z1)
    dif_ave_ave_9keV_z1 = frac_diff(ave_ave_cdm_plot_z1, ave_ave_9keV_plot_z1)
    # now the realizations, starting with 21cmFAST 
    dif_r1_ave_3keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_3keV_plot_z1)
    dif_r1_ave_4keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_4keV_plot_z1)
    dif_r1_ave_6keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_6keV_plot_z1)
    dif_r1_ave_9keV_z1 = frac_diff(r1_ave_cdm_plot_z1, r1_ave_9keV_plot_z1)

    dif_r2_ave_3keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_3keV_plot_z1)
    dif_r2_ave_4keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_4keV_plot_z1)
    dif_r2_ave_6keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_6keV_plot_z1)
    dif_r2_ave_9keV_z1 = frac_diff(r2_ave_cdm_plot_z1, r2_ave_9keV_plot_z1)

    dif_r3_ave_3keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_3keV_plot_z1)
    dif_r3_ave_4keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_4keV_plot_z1)
    dif_r3_ave_6keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_6keV_plot_z1)
    dif_r3_ave_9keV_z1 = frac_diff(r3_ave_cdm_plot_z1, r3_ave_9keV_plot_z1)

    dif_r4_ave_3keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_3keV_plot_z1)
    dif_r4_ave_4keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_4keV_plot_z1)
    dif_r4_ave_6keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_6keV_plot_z1)
    dif_r4_ave_9keV_z1 = frac_diff(r4_ave_cdm_plot_z1, r4_ave_9keV_plot_z1)
    # now gadget realizations
    dif_ave_r1_3keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_3keV_plot_z1)
    dif_ave_r1_4keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_4keV_plot_z1)
    dif_ave_r1_6keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_6keV_plot_z1)
    dif_ave_r1_9keV_z1 = frac_diff(ave_r1_cdm_plot_z1, ave_r1_9keV_plot_z1)

    dif_ave_r2_3keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_3keV_plot_z1)
    dif_ave_r2_4keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_4keV_plot_z1)
    dif_ave_r2_6keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_6keV_plot_z1)
    dif_ave_r2_9keV_z1 = frac_diff(ave_r2_cdm_plot_z1, ave_r2_9keV_plot_z1)

    dif_ave_r3_3keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_3keV_plot_z1)
    dif_ave_r3_4keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_4keV_plot_z1)
    dif_ave_r3_6keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_6keV_plot_z1)
    dif_ave_r3_9keV_z1 = frac_diff(ave_r3_cdm_plot_z1, ave_r3_9keV_plot_z1)

    dif_ave_r4_3keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_3keV_plot_z1)
    dif_ave_r4_4keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_4keV_plot_z1)
    dif_ave_r4_6keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_6keV_plot_z1)
    dif_ave_r4_9keV_z1 = frac_diff(ave_r4_cdm_plot_z1, ave_r4_9keV_plot_z1)
    # and the next redshift
    # first the "mean" one
    dif_ave_ave_3keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_3keV_plot_z5)
    dif_ave_ave_4keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_4keV_plot_z5)
    dif_ave_ave_6keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_6keV_plot_z5)
    dif_ave_ave_9keV_z5 = frac_diff(ave_ave_cdm_plot_z5, ave_ave_9keV_plot_z5)
    # now the realizations, starting with 21cmFAST 
    dif_r1_ave_3keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_3keV_plot_z5)
    dif_r1_ave_4keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_4keV_plot_z5)
    dif_r1_ave_6keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_6keV_plot_z5)
    dif_r1_ave_9keV_z5 = frac_diff(r1_ave_cdm_plot_z5, r1_ave_9keV_plot_z5)

    dif_r2_ave_3keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_3keV_plot_z5)
    dif_r2_ave_4keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_4keV_plot_z5)
    dif_r2_ave_6keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_6keV_plot_z5)
    dif_r2_ave_9keV_z5 = frac_diff(r2_ave_cdm_plot_z5, r2_ave_9keV_plot_z5)

    dif_r3_ave_3keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_3keV_plot_z5)
    dif_r3_ave_4keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_4keV_plot_z5)
    dif_r3_ave_6keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_6keV_plot_z5)
    dif_r3_ave_9keV_z5 = frac_diff(r3_ave_cdm_plot_z5, r3_ave_9keV_plot_z5)

    dif_r4_ave_3keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_3keV_plot_z5)
    dif_r4_ave_4keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_4keV_plot_z5)
    dif_r4_ave_6keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_6keV_plot_z5)
    dif_r4_ave_9keV_z5 = frac_diff(r4_ave_cdm_plot_z5, r4_ave_9keV_plot_z5)
    # now gadget realizations
    dif_ave_r1_3keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_3keV_plot_z5)
    dif_ave_r1_4keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_4keV_plot_z5)
    dif_ave_r1_6keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_6keV_plot_z5)
    dif_ave_r1_9keV_z5 = frac_diff(ave_r1_cdm_plot_z5, ave_r1_9keV_plot_z5)

    dif_ave_r2_3keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_3keV_plot_z5)
    dif_ave_r2_4keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_4keV_plot_z5)
    dif_ave_r2_6keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_6keV_plot_z5)
    dif_ave_r2_9keV_z5 = frac_diff(ave_r2_cdm_plot_z5, ave_r2_9keV_plot_z5)

    dif_ave_r3_3keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_3keV_plot_z5)
    dif_ave_r3_4keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_4keV_plot_z5)
    dif_ave_r3_6keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_6keV_plot_z5)
    dif_ave_r3_9keV_z5 = frac_diff(ave_r3_cdm_plot_z5, ave_r3_9keV_plot_z5)

    dif_ave_r4_3keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_3keV_plot_z5)
    dif_ave_r4_4keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_4keV_plot_z5)
    dif_ave_r4_6keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_6keV_plot_z5)
    dif_ave_r4_9keV_z5 = frac_diff(ave_r4_cdm_plot_z5, ave_r4_9keV_plot_z5)


# now we can compute the sample variance on the fractional difference
dif_ave_ave_3keV_error_z1 = sample_variance(dif_ave_ave_3keV_z1, dif_r1_ave_3keV_z1, dif_r2_ave_3keV_z1, dif_r3_ave_3keV_z1, dif_r4_ave_3keV_z1, dif_ave_r1_3keV_z1, dif_ave_r2_3keV_z1, dif_ave_r3_3keV_z1, dif_ave_r4_3keV_z1)
dif_ave_ave_4keV_error_z1 = sample_variance(dif_ave_ave_4keV_z1, dif_r1_ave_4keV_z1, dif_r2_ave_4keV_z1, dif_r3_ave_4keV_z1, dif_r4_ave_4keV_z1, dif_ave_r1_4keV_z1, dif_ave_r2_4keV_z1, dif_ave_r3_4keV_z1, dif_ave_r4_4keV_z1)
dif_ave_ave_6keV_error_z1 = sample_variance(dif_ave_ave_6keV_z1, dif_r1_ave_6keV_z1, dif_r2_ave_6keV_z1, dif_r3_ave_6keV_z1, dif_r4_ave_6keV_z1, dif_ave_r1_6keV_z1, dif_ave_r2_6keV_z1, dif_ave_r3_6keV_z1, dif_ave_r4_6keV_z1)
dif_ave_ave_9keV_error_z1 = sample_variance(dif_ave_ave_9keV_z1, dif_r1_ave_9keV_z1, dif_r2_ave_9keV_z1, dif_r3_ave_9keV_z1, dif_r4_ave_9keV_z1, dif_ave_r1_9keV_z1, dif_ave_r2_9keV_z1, dif_ave_r3_9keV_z1, dif_ave_r4_9keV_z1)
# other redshift
dif_ave_ave_3keV_error_z5 = sample_variance(dif_ave_ave_3keV_z5, dif_r1_ave_3keV_z5, dif_r2_ave_3keV_z5, dif_r3_ave_3keV_z5, dif_r4_ave_3keV_z5, dif_ave_r1_3keV_z5, dif_ave_r2_3keV_z5, dif_ave_r3_3keV_z5, dif_ave_r4_3keV_z5)
dif_ave_ave_4keV_error_z5 = sample_variance(dif_ave_ave_4keV_z5, dif_r1_ave_4keV_z5, dif_r2_ave_4keV_z5, dif_r3_ave_4keV_z5, dif_r4_ave_4keV_z5, dif_ave_r1_4keV_z5, dif_ave_r2_4keV_z5, dif_ave_r3_4keV_z5, dif_ave_r4_4keV_z5)
dif_ave_ave_6keV_error_z5 = sample_variance(dif_ave_ave_6keV_z5, dif_r1_ave_6keV_z5, dif_r2_ave_6keV_z5, dif_r3_ave_6keV_z5, dif_r4_ave_6keV_z5, dif_ave_r1_6keV_z5, dif_ave_r2_6keV_z5, dif_ave_r3_6keV_z5, dif_ave_r4_6keV_z5)
dif_ave_ave_9keV_error_z5 = sample_variance(dif_ave_ave_9keV_z5, dif_r1_ave_9keV_z5, dif_r2_ave_9keV_z5, dif_r3_ave_9keV_z5, dif_r4_ave_9keV_z5, dif_ave_r1_9keV_z5, dif_ave_r2_9keV_z5, dif_ave_r3_9keV_z5, dif_ave_r4_9keV_z5)

# if mini_halos == True:
#     dif_ave_ave_cdm_error_z1 = sample_variance(dif_ave_ave_cdm_z1, dif_r1_ave_cdm_z1, dif_r2_ave_cdm_z1, dif_r3_ave_cdm_z1, dif_r4_ave_cdm_z1, dif_ave_r1_cdm_z1, dif_ave_r2_cdm_z1, dif_ave_r3_cdm_z1, dif_ave_r4_cdm_z1)
#     dif_ave_ave_cdm_error_z5 = sample_variance(dif_ave_ave_cdm_z5, dif_r1_ave_cdm_z5, dif_r2_ave_cdm_z5, dif_r3_ave_cdm_z5, dif_r4_ave_cdm_z5, dif_ave_r1_cdm_z5, dif_ave_r2_cdm_z5, dif_ave_r3_cdm_z5, dif_ave_r4_cdm_z5)

# %%
if mini_halos == True:
    n = 5
    colors = plt.cm.viridis(np.linspace(0,1,n))
    labels = [r'CDM-MH', r'm$_{\rm wdm} = 9$ keV', r'm$_{\rm wdm} = 6$ keV', r'm$_{\rm wdm} = 4$ keV', r'm$_{\rm wdm} = 3$ keV']
    mean_table_z1 = np.zeros((len(k_array),n))
    error_table_z1 = np.zeros((len(k_array),n))
    mean_table_z5 = np.zeros((len(k_array),n))
    error_table_z5 = np.zeros((len(k_array),n))

#     mean_table_z1[:,0] = fid_ave_ave_cdm_plot_z1[:]
    mean_table_z1[:,0] = ave_ave_cdm_plot_z1[:]
    mean_table_z1[:,1] = ave_ave_9keV_plot_z1[:]
    mean_table_z1[:,2] = ave_ave_6keV_plot_z1[:]
    mean_table_z1[:,3] = ave_ave_4keV_plot_z1[:]
    mean_table_z1[:,4] = ave_ave_3keV_plot_z1[:]
    
#     error_table_z1[:,0] = fid_ave_ave_cdm_error_z1[:]
    error_table_z1[:,0] = ave_ave_cdm_error_z1[:]
    error_table_z1[:,1] = ave_ave_9keV_error_z1[:]
    error_table_z1[:,2] = ave_ave_6keV_error_z1[:]
    error_table_z1[:,3] = ave_ave_4keV_error_z1[:]
    error_table_z1[:,4] = ave_ave_3keV_error_z1[:]

#     mean_table_z5[:,0] = fid_ave_ave_cdm_plot_z5[:]
    mean_table_z5[:,0] = ave_ave_cdm_plot_z5[:]
    mean_table_z5[:,1] = ave_ave_9keV_plot_z5[:]
    mean_table_z5[:,2] = ave_ave_6keV_plot_z5[:]
    mean_table_z5[:,3] = ave_ave_4keV_plot_z5[:]
    mean_table_z5[:,4] = ave_ave_3keV_plot_z5[:]
    
#     error_table_z5[:,0] = fid_ave_ave_cdm_error_z5[:]
    error_table_z5[:,0] = ave_ave_cdm_error_z5[:]
    error_table_z5[:,1] = ave_ave_9keV_error_z5[:]
    error_table_z5[:,2] = ave_ave_6keV_error_z5[:]
    error_table_z5[:,3] = ave_ave_4keV_error_z5[:]
    error_table_z5[:,4] = ave_ave_3keV_error_z5[:]
    
    dif_colors = plt.cm.viridis(np.linspace(0.2,1,n-1))
    dif_labels = [r'm$_{\rm wdm} = 9$ keV', r'm$_{\rm wdm} = 6$ keV', r'm$_{\rm wdm} = 4$ keV', r'm$_{\rm wdm} = 3$ keV']
    dif_mean_z1 = np.zeros((len(k_array),n-1))
    dif_error_z1 = np.zeros((len(k_array),n-1))
    dif_mean_z5 = np.zeros((len(k_array),n-1))
    dif_error_z5 = np.zeros((len(k_array),n-1))

#     dif_mean_z1[:,0] = dif_ave_ave_cdm_z1[:]
    dif_mean_z1[:,0] = dif_ave_ave_9keV_z1[:]
    dif_mean_z1[:,1] = dif_ave_ave_6keV_z1[:]
    dif_mean_z1[:,2] = dif_ave_ave_4keV_z1[:]
    dif_mean_z1[:,3] = dif_ave_ave_3keV_z1[:]

#     dif_error_z1[:,0] = dif_ave_ave_cdm_error_z1[:]
    dif_error_z1[:,0] = dif_ave_ave_9keV_error_z1[:]
    dif_error_z1[:,1] = dif_ave_ave_6keV_error_z1[:]
    dif_error_z1[:,2] = dif_ave_ave_4keV_error_z1[:]
    dif_error_z1[:,3] = dif_ave_ave_3keV_error_z1[:]

#     dif_mean_z5[:,0] = dif_ave_ave_cdm_z5[:]
    dif_mean_z5[:,0] = dif_ave_ave_9keV_z5[:]
    dif_mean_z5[:,1] = dif_ave_ave_6keV_z5[:]
    dif_mean_z5[:,2] = dif_ave_ave_4keV_z5[:]
    dif_mean_z5[:,3] = dif_ave_ave_3keV_z5[:]

#     dif_error_z5[:,0] = dif_ave_ave_cdm_error_z5[:]
    dif_error_z5[:,0] = dif_ave_ave_9keV_error_z5[:]
    dif_error_z5[:,1] = dif_ave_ave_6keV_error_z5[:]
    dif_error_z5[:,2] = dif_ave_ave_4keV_error_z5[:]
    dif_error_z5[:,3] = dif_ave_ave_3keV_error_z5[:]
else:
    n = 5
    colors = plt.cm.viridis(np.linspace(0,1,n))
    labels = [r'CDM', r'm$_{\rm wdm} = 9$ keV', r'm$_{\rm wdm} = 6$ keV', r'm$_{\rm wdm} = 4$ keV', r'm$_{\rm wdm} = 3$ keV']

    mean_table_z1 = np.zeros((len(k_array),n))
    error_table_z1 = np.zeros((len(k_array),n))
    mean_table_z5 = np.zeros((len(k_array),n))
    error_table_z5 = np.zeros((len(k_array),n))

    mean_table_z1[:,0] = ave_ave_cdm_plot_z1[:]
    mean_table_z1[:,1] = ave_ave_9keV_plot_z1[:]
    mean_table_z1[:,2] = ave_ave_6keV_plot_z1[:]
    mean_table_z1[:,3] = ave_ave_4keV_plot_z1[:]
    mean_table_z1[:,4] = ave_ave_3keV_plot_z1[:]

    error_table_z1[:,0] = ave_ave_cdm_error_z1[:]
    error_table_z1[:,1] = ave_ave_9keV_error_z1[:]
    error_table_z1[:,2] = ave_ave_6keV_error_z1[:]
    error_table_z1[:,3] = ave_ave_4keV_error_z1[:]
    error_table_z1[:,4] = ave_ave_3keV_error_z1[:]

    mean_table_z5[:,0] = ave_ave_cdm_plot_z5[:]
    mean_table_z5[:,1] = ave_ave_9keV_plot_z5[:]
    mean_table_z5[:,2] = ave_ave_6keV_plot_z5[:]
    mean_table_z5[:,3] = ave_ave_4keV_plot_z5[:]
    mean_table_z5[:,4] = ave_ave_3keV_plot_z5[:]

    error_table_z5[:,0] = ave_ave_cdm_error_z5[:]
    error_table_z5[:,1] = ave_ave_9keV_error_z5[:]
    error_table_z5[:,2] = ave_ave_6keV_error_z5[:]
    error_table_z5[:,3] = ave_ave_4keV_error_z5[:]
    error_table_z5[:,4] = ave_ave_3keV_error_z5[:]


    dif_colors = plt.cm.viridis(np.linspace(0.2,1,n-1))
    dif_labels = [r'm$_{\rm wdm} = 9$ keV', r'm$_{\rm wdm} = 6$ keV', r'm$_{\rm wdm} = 4$ keV', r'm$_{\rm wdm} = 3$ keV']
    dif_mean_z1 = np.zeros((len(k_array),n-1))
    dif_error_z1 = np.zeros((len(k_array),n-1))
    dif_mean_z5 = np.zeros((len(k_array),n-1))
    dif_error_z5 = np.zeros((len(k_array),n-1))

    dif_mean_z1[:,0] = dif_ave_ave_9keV_z1[:]
    dif_mean_z1[:,1] = dif_ave_ave_6keV_z1[:]
    dif_mean_z1[:,2] = dif_ave_ave_4keV_z1[:]
    dif_mean_z1[:,3] = dif_ave_ave_3keV_z1[:]

    dif_error_z1[:,0] = dif_ave_ave_9keV_error_z1[:]
    dif_error_z1[:,1] = dif_ave_ave_6keV_error_z1[:]
    dif_error_z1[:,2] = dif_ave_ave_4keV_error_z1[:]
    dif_error_z1[:,3] = dif_ave_ave_3keV_error_z1[:]

    dif_mean_z5[:,0] = dif_ave_ave_9keV_z5[:]
    dif_mean_z5[:,1] = dif_ave_ave_6keV_z5[:]
    dif_mean_z5[:,2] = dif_ave_ave_4keV_z5[:]
    dif_mean_z5[:,3] = dif_ave_ave_3keV_z5[:]

    dif_error_z5[:,0] = dif_ave_ave_9keV_error_z5[:]
    dif_error_z5[:,1] = dif_ave_ave_6keV_error_z5[:]
    dif_error_z5[:,2] = dif_ave_ave_4keV_error_z5[:]
    dif_error_z5[:,3] = dif_ave_ave_3keV_error_z5[:]

# %%
# plotting, need two columns one per redshift
fig, axs = plt.subplots(2, 2,figsize=(12,12), sharex=True)
for i in range(n):
    axs[0,0].fill_between(k_array, mean_table_z1[:,i] - error_table_z1[:,i], mean_table_z1[:,i] + error_table_z1[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
    axs[0,1].fill_between(k_array, mean_table_z5[:,i] - error_table_z5[:,i], mean_table_z5[:,i] + error_table_z5[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
# axs[0,0].errorbar(k_array, ave_ave_cdm_plot_z1, yerr=ave_ave_cdm_error_z1, fmt='-o', color='royalblue', label=r'CDM, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_3keV_plot_z1, yerr=ave_ave_3keV_error_z1, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_4keV_plot_z1, yerr=ave_ave_4keV_error_z1, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_6keV_plot_z1, yerr=ave_ave_6keV_error_z1, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_9keV_plot_z1, yerr=ave_ave_9keV_error_z1, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV, $z = 2$')
axs[0,0].grid(linestyle='dotted')
axs[0,0].set_title('Redshift = 2', fontsize=16)
axs[0,0].tick_params(axis = 'both', which = 'major', labelsize = 14)
axs[0,0].set_ylabel(r'3D Flux power spectrum    [Mpc$^3$]', fontsize=16)
axs[0,0].set_xscale('log')
axs[0,0].legend(loc='best',fontsize=14)
axs[0,0].set_xlim(0.05, 1.1)
axs[0,0].set_ylim(0,100)
# other redshift
# axs[0,1].errorbar(k_array, ave_ave_cdm_plot_z5, yerr=ave_ave_cdm_error_z5, fmt='-o', color='royalblue', label=r'CDM, $z = 4$')
# axs[0,1].errorbar(k_array, ave_ave_3keV_plot_z5, yerr=ave_ave_3keV_error_z5, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z = 4$')
# axs[0,1].errorbar(k_array, ave_ave_4keV_plot_z5, yerr=ave_ave_4keV_error_z5, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z = 4$')
# axs[0,1].errorbar(k_array, ave_ave_6keV_plot_z5, yerr=ave_ave_6keV_error_z5, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z = 4$')
# axs[0,1].errorbar(k_array, ave_ave_9keV_plot_z5, yerr=ave_ave_9keV_error_z5, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV, $z = 4$')
axs[0,1].grid(linestyle='dotted')
axs[0,1].set_title('Redshift = 4', fontsize=16)
axs[0,1].set_xscale('log')
axs[0,1].tick_params(axis = 'both', which = 'major', labelsize = 14)
axs[0,1].set_ylim(0,1000)
# axs[0,1].set_ylabel(r'3D Flux power spectrum    [Mpc]', fontsize=16)
# and the fractional difference
for i in range(n-1):
    axs[1,0].fill_between(k_array, dif_mean_z1[:,i] - dif_error_z1[:,1], dif_mean_z1[:,i] + dif_error_z1[:,1], facecolor=dif_colors[i], edgecolor=dif_colors[i], label=dif_labels[i])
    axs[1,1].fill_between(k_array, dif_mean_z5[:,i] - dif_error_z5[:,1], dif_mean_z5[:,i] + dif_error_z5[:,1], facecolor=dif_colors[i], edgecolor=dif_colors[i], label=dif_labels[i])
# axs[1,0].errorbar(k_array, dif_ave_ave_3keV_z1, yerr=dif_ave_ave_3keV_error_z1, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z=2$')
# axs[1,0].errorbar(k_array, dif_ave_ave_4keV_z1, yerr=dif_ave_ave_4keV_error_z1, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z=2$')
# axs[1,0].errorbar(k_array, dif_ave_ave_6keV_z1, yerr=dif_ave_ave_6keV_error_z1, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z=2$')
# axs[1,0].errorbar(k_array, dif_ave_ave_9keV_z1, yerr=dif_ave_ave_9keV_error_z1, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV, $z=2$')
axs[1,0].grid(linestyle='dotted')
axs[1,0].set_xscale('log')
axs[1,0].set_xlabel('k   [Mpc$^{-1}$]', fontsize=16)
axs[1,0].tick_params(axis = 'both', which = 'major', labelsize = 14)
axs[1,0].set_ylabel(r'Frac. diff.    [%]', fontsize=16)
axs[1,0].set_xlim(0.05, 1.1)
axs[1,0].set_ylim(0., 2.2)
# axs[1,0].legend(loc='best',fontsize=14)
# and the other redshift
# axs[1,1].errorbar(k_array, dif_ave_ave_3keV_z5, yerr=dif_ave_ave_3keV_error_z5, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_4keV_z5, yerr=dif_ave_ave_4keV_error_z5, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_6keV_z5, yerr=dif_ave_ave_6keV_error_z5, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_9keV_z5, yerr=dif_ave_ave_9keV_error_z5, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV,$z=4$')
axs[1,1].grid(linestyle='dotted')
axs[1,1].set_xscale('log')
axs[1,1].set_xlabel('k   [Mpc$^{-1}$]', fontsize=16)
axs[1,1].tick_params(axis = 'both', which = 'major', labelsize = 14)
# axs[1,1].set_ylabel(r'Frac. diff.    [%]', fontsize=16)
axs[1,1].set_xlim(0.05, 1.1)
axs[1,1].set_ylim(0., 21)
fig.tight_layout()
if mini_halos == True:
    plt.savefig('mh_3D_power_w_errors.pdf')
else:
    plt.savefig('3D_power_w_errors.pdf')
plt.show()

# %%
# plotting, need two columns one per redshift
fig, axs = plt.subplots(1, 2,figsize=(12,6), sharex=True)
for i in range(n):
    axs[0].fill_between(k_array, mean_table_z5[:,i] - error_table_z5[:,i], mean_table_z5[:,i] + error_table_z5[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
# axs[0,0].errorbar(k_array, ave_ave_cdm_plot_z1, yerr=ave_ave_cdm_error_z1, fmt='-o', color='royalblue', label=r'CDM, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_3keV_plot_z1, yerr=ave_ave_3keV_error_z1, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_4keV_plot_z1, yerr=ave_ave_4keV_error_z1, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_6keV_plot_z1, yerr=ave_ave_6keV_error_z1, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z = 2$')
# axs[0,0].errorbar(k_array, ave_ave_9keV_plot_z1, yerr=ave_ave_9keV_error_z1, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV, $z = 2$')
axs[0].set_ylabel(r'3D Flux power spectrum    [Mpc$^3$]', fontsize=16)
# other redshift
axs[0].grid(linestyle='dotted')
axs[0].set_title('Redshift = 4', fontsize=16)
axs[0].set_xscale('log')
axs[0].tick_params(axis = 'both', which = 'major', labelsize = 14)
axs[0].set_ylim(0,1000)
axs[0].set_xlabel('k   [Mpc$^{-1}$]', fontsize=16)
axs[0].legend(loc='best',fontsize=14)
# axs[0,1].set_ylabel(r'3D Flux power spectrum    [Mpc]', fontsize=16)
# and the fractional difference
for i in range(n-1):
    axs[1].fill_between(k_array, dif_mean_z5[:,i] - dif_error_z5[:,1], dif_mean_z5[:,i] + dif_error_z5[:,1], facecolor=dif_colors[i], edgecolor=dif_colors[i], label=dif_labels[i])
# and the other redshift
# axs[1,1].errorbar(k_array, dif_ave_ave_3keV_z5, yerr=dif_ave_ave_3keV_error_z5, fmt=':s', color='magenta', label=r'$m_{\rm wdm} = 3$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_4keV_z5, yerr=dif_ave_ave_4keV_error_z5, fmt=':d', color='orange', label=r'$m_{\rm wdm} = 4$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_6keV_z5, yerr=dif_ave_ave_6keV_error_z5, fmt='--p', color='purple', label=r'$m_{\rm wdm} = 6$ keV, $z=4$')
# axs[1,1].errorbar(k_array, dif_ave_ave_9keV_z5, yerr=dif_ave_ave_9keV_error_z5, fmt='-.*', color='green', label=r'$m_{\rm wdm} = 9$ keV,$z=4$')
axs[1].grid(linestyle='dotted')
axs[1].set_xscale('log')
axs[1].set_xlabel('k   [Mpc$^{-1}$]', fontsize=16)
axs[1].set_title('Redshift = 4', fontsize=16)
axs[1].tick_params(axis = 'both', which = 'major', labelsize = 14)
# axs[1,1].set_ylabel(r'Frac. diff.    [%]', fontsize=16)
axs[1].set_xlim(0.05, 1.1)
axs[1].set_ylim(0., 12)
axs[1].set_ylabel(r'Frac. diff.    [%]', fontsize=16)
fig.tight_layout()
if mini_halos == True:
    plt.savefig('mh_3D_power_w_errors_for_talk.pdf')
else:
    plt.savefig('3D_power_w_errors_for_talk.pdf')
plt.show()

# %%
"""
Note for myself: Results seems a little suspect, perhaps take a closer look at Catalina's data.
"""
# Out:
# "\nNote for myself: Results seems a little suspect, perhaps take a closer look at Catalina's data.\n"

# %%
"""Something weird, CDM has a more delayed reio so where is it in previous plot?"""
# fid_ave_ave_cdm.FluxP3D_lya_Mpc(z5, 0.1, 0.1) + fid_ave_ave_cdm.FluxP3D_reio_Mpc(z5, 0.1, 0.1)
# Out:
# 'Something weird, CDM has a more delayed reio so where is it in previous plot?'

# %%
ave_ave_3keV.FluxP3D_lya_Mpc(z5, 0.1, 0.1) + ave_ave_3keV.FluxP3D_reio_Mpc(z5, 0.1, 0.1)
# Out:
# array([202.51737567])

# %%
# luckily for the transparency data only gadget sims matter, so
# now we want a transparency plot
z_re = np.linspace(6.0, 12.0, 30)
psi_ave_cdm_z1 = np.zeros(len(z_re))
psi_ave_3keV_z1 = np.zeros(len(z_re))
psi_ave_4keV_z1 = np.zeros(len(z_re))
psi_ave_6keV_z1 = np.zeros(len(z_re))
psi_ave_9keV_z1 = np.zeros(len(z_re))

psi_ave_cdm_z3 = np.zeros(len(z_re))
psi_ave_3keV_z3 = np.zeros(len(z_re))
psi_ave_4keV_z3 = np.zeros(len(z_re))
psi_ave_6keV_z3 = np.zeros(len(z_re))
psi_ave_9keV_z3 = np.zeros(len(z_re))

psi_ave_cdm_z5 = np.zeros(len(z_re))
psi_ave_3keV_z5 = np.zeros(len(z_re))
psi_ave_4keV_z5 = np.zeros(len(z_re))
psi_ave_6keV_z5 = np.zeros(len(z_re))
psi_ave_9keV_z5 = np.zeros(len(z_re))

psi_r1_cdm_z1 = np.zeros(len(z_re))
psi_r2_cdm_z1 = np.zeros(len(z_re))
psi_r3_cdm_z1 = np.zeros(len(z_re))
psi_r4_cdm_z1 = np.zeros(len(z_re))

psi_r1_3keV_z1 = np.zeros(len(z_re))
psi_r2_3keV_z1 = np.zeros(len(z_re))
psi_r3_3keV_z1 = np.zeros(len(z_re))
psi_r4_3keV_z1 = np.zeros(len(z_re))

psi_r1_4keV_z1 = np.zeros(len(z_re))
psi_r2_4keV_z1 = np.zeros(len(z_re))
psi_r3_4keV_z1 = np.zeros(len(z_re))
psi_r4_4keV_z1 = np.zeros(len(z_re))

psi_r1_6keV_z1 = np.zeros(len(z_re))
psi_r2_6keV_z1 = np.zeros(len(z_re))
psi_r3_6keV_z1 = np.zeros(len(z_re))
psi_r4_6keV_z1 = np.zeros(len(z_re))

psi_r1_9keV_z1 = np.zeros(len(z_re))
psi_r2_9keV_z1 = np.zeros(len(z_re))
psi_r3_9keV_z1 = np.zeros(len(z_re))
psi_r4_9keV_z1 = np.zeros(len(z_re))

psi_r1_cdm_z3 = np.zeros(len(z_re))
psi_r2_cdm_z3 = np.zeros(len(z_re))
psi_r3_cdm_z3 = np.zeros(len(z_re))
psi_r4_cdm_z3 = np.zeros(len(z_re))

psi_r1_3keV_z3 = np.zeros(len(z_re))
psi_r2_3keV_z3 = np.zeros(len(z_re))
psi_r3_3keV_z3 = np.zeros(len(z_re))
psi_r4_3keV_z3 = np.zeros(len(z_re))

psi_r1_4keV_z3 = np.zeros(len(z_re))
psi_r2_4keV_z3 = np.zeros(len(z_re))
psi_r3_4keV_z3 = np.zeros(len(z_re))
psi_r4_4keV_z3 = np.zeros(len(z_re))

psi_r1_6keV_z3 = np.zeros(len(z_re))
psi_r2_6keV_z3 = np.zeros(len(z_re))
psi_r3_6keV_z3 = np.zeros(len(z_re))
psi_r4_6keV_z3 = np.zeros(len(z_re))

psi_r1_9keV_z3 = np.zeros(len(z_re))
psi_r2_9keV_z3 = np.zeros(len(z_re))
psi_r3_9keV_z3 = np.zeros(len(z_re))
psi_r4_9keV_z3 = np.zeros(len(z_re))

psi_r1_cdm_z5 = np.zeros(len(z_re))
psi_r2_cdm_z5 = np.zeros(len(z_re))
psi_r3_cdm_z5 = np.zeros(len(z_re))
psi_r4_cdm_z5 = np.zeros(len(z_re))

psi_r1_3keV_z5 = np.zeros(len(z_re))
psi_r2_3keV_z5 = np.zeros(len(z_re))
psi_r3_3keV_z5 = np.zeros(len(z_re))
psi_r4_3keV_z5 = np.zeros(len(z_re))

psi_r1_4keV_z5 = np.zeros(len(z_re))
psi_r2_4keV_z5 = np.zeros(len(z_re))
psi_r3_4keV_z5 = np.zeros(len(z_re))
psi_r4_4keV_z5 = np.zeros(len(z_re))

psi_r1_6keV_z5 = np.zeros(len(z_re))
psi_r2_6keV_z5 = np.zeros(len(z_re))
psi_r3_6keV_z5 = np.zeros(len(z_re))
psi_r4_6keV_z5 = np.zeros(len(z_re))

psi_r1_9keV_z5 = np.zeros(len(z_re))
psi_r2_9keV_z5 = np.zeros(len(z_re))
psi_r3_9keV_z5 = np.zeros(len(z_re))
psi_r4_9keV_z5 = np.zeros(len(z_re))

for i in range(0, len(z_re)):
    psi_ave_cdm_z1[i] = ave_ave_cdm.transparency(z_re[i], 2.0)
    psi_ave_3keV_z1[i] = ave_ave_3keV.transparency(z_re[i], 2.0)
    psi_ave_4keV_z1[i] = ave_ave_4keV.transparency(z_re[i], 2.0)
    psi_ave_6keV_z1[i] = ave_ave_6keV.transparency(z_re[i], 2.0)
    psi_ave_9keV_z1[i] = ave_ave_9keV.transparency(z_re[i], 2.0)
    
    psi_ave_cdm_z3[i]  = ave_ave_cdm.transparency(z_re[i], 3.0)
    psi_ave_3keV_z3[i] = ave_ave_3keV.transparency(z_re[i], 3.0)
    psi_ave_4keV_z3[i] = ave_ave_4keV.transparency(z_re[i], 3.0)
    psi_ave_6keV_z3[i] = ave_ave_6keV.transparency(z_re[i], 3.0)
    psi_ave_9keV_z3[i] = ave_ave_9keV.transparency(z_re[i], 3.0)
    
    psi_ave_cdm_z5[i] = ave_ave_cdm.transparency(z_re[i], 4.0)
    psi_ave_3keV_z5[i] = ave_ave_3keV.transparency(z_re[i], 4.0)
    psi_ave_4keV_z5[i] = ave_ave_4keV.transparency(z_re[i], 4.0)
    psi_ave_6keV_z5[i] = ave_ave_6keV.transparency(z_re[i], 4.0)
    psi_ave_9keV_z5[i] = ave_ave_9keV.transparency(z_re[i], 4.0)
    
    psi_r1_cdm_z1[i] = ave_r1_cdm.transparency(z_re[i], 2.0)
    psi_r2_cdm_z1[i] = ave_r2_cdm.transparency(z_re[i], 2.0)
    psi_r3_cdm_z1[i] = ave_r3_cdm.transparency(z_re[i], 2.0)
    psi_r4_cdm_z1[i] = ave_r4_cdm.transparency(z_re[i], 2.0)
    
    psi_r1_3keV_z1[i] = ave_r1_3keV.transparency(z_re[i], 2.0)
    psi_r2_3keV_z1[i] = ave_r2_3keV.transparency(z_re[i], 2.0)
    psi_r3_3keV_z1[i] = ave_r3_3keV.transparency(z_re[i], 2.0)
    psi_r4_3keV_z1[i] = ave_r4_3keV.transparency(z_re[i], 2.0)
    
    psi_r1_4keV_z1[i] = ave_r1_4keV.transparency(z_re[i], 2.0)
    psi_r2_4keV_z1[i] = ave_r2_4keV.transparency(z_re[i], 2.0)
    psi_r3_4keV_z1[i] = ave_r3_4keV.transparency(z_re[i], 2.0)
    psi_r4_4keV_z1[i] = ave_r4_4keV.transparency(z_re[i], 2.0)
    
    psi_r1_6keV_z1[i] = ave_r1_6keV.transparency(z_re[i], 2.0)
    psi_r2_6keV_z1[i] = ave_r2_6keV.transparency(z_re[i], 2.0)
    psi_r3_6keV_z1[i] = ave_r3_6keV.transparency(z_re[i], 2.0)
    psi_r4_6keV_z1[i] = ave_r4_6keV.transparency(z_re[i], 2.0)
    
    psi_r1_9keV_z1[i] = ave_r1_9keV.transparency(z_re[i], 2.0)
    psi_r2_9keV_z1[i] = ave_r2_9keV.transparency(z_re[i], 2.0)
    psi_r3_9keV_z1[i] = ave_r3_9keV.transparency(z_re[i], 2.0)
    psi_r4_9keV_z1[i] = ave_r4_9keV.transparency(z_re[i], 2.0)
    
    # next redshift
    psi_r1_cdm_z3[i] = ave_r1_cdm.transparency(z_re[i], 3.0)
    psi_r2_cdm_z3[i] = ave_r2_cdm.transparency(z_re[i], 3.0)
    psi_r3_cdm_z3[i] = ave_r3_cdm.transparency(z_re[i], 3.0)
    psi_r4_cdm_z3[i] = ave_r4_cdm.transparency(z_re[i], 3.0)
    
    psi_r1_3keV_z3[i] = ave_r1_3keV.transparency(z_re[i], 3.0)
    psi_r2_3keV_z3[i] = ave_r2_3keV.transparency(z_re[i], 3.0)
    psi_r3_3keV_z3[i] = ave_r3_3keV.transparency(z_re[i], 3.0)
    psi_r4_3keV_z3[i] = ave_r4_3keV.transparency(z_re[i], 3.0)
    
    psi_r1_4keV_z3[i] = ave_r1_4keV.transparency(z_re[i], 3.0)
    psi_r2_4keV_z3[i] = ave_r2_4keV.transparency(z_re[i], 3.0)
    psi_r3_4keV_z3[i] = ave_r3_4keV.transparency(z_re[i], 3.0)
    psi_r4_4keV_z3[i] = ave_r4_4keV.transparency(z_re[i], 3.0)
    
    psi_r1_6keV_z3[i] = ave_r1_6keV.transparency(z_re[i], 3.0)
    psi_r2_6keV_z3[i] = ave_r2_6keV.transparency(z_re[i], 3.0)
    psi_r3_6keV_z3[i] = ave_r3_6keV.transparency(z_re[i], 3.0)
    psi_r4_6keV_z3[i] = ave_r4_6keV.transparency(z_re[i], 3.0)
    
    psi_r1_9keV_z3[i] = ave_r1_9keV.transparency(z_re[i], 3.0)
    psi_r2_9keV_z3[i] = ave_r2_9keV.transparency(z_re[i], 3.0)
    psi_r3_9keV_z3[i] = ave_r3_9keV.transparency(z_re[i], 3.0)
    psi_r4_9keV_z3[i] = ave_r4_9keV.transparency(z_re[i], 3.0)
    
    # next redshift
    psi_r1_cdm_z5[i] = ave_r1_cdm.transparency(z_re[i], 4.0)
    psi_r2_cdm_z5[i] = ave_r2_cdm.transparency(z_re[i], 4.0)
    psi_r3_cdm_z5[i] = ave_r3_cdm.transparency(z_re[i], 4.0)
    psi_r4_cdm_z5[i] = ave_r4_cdm.transparency(z_re[i], 4.0)
    
    psi_r1_3keV_z5[i] = ave_r1_3keV.transparency(z_re[i], 4.0)
    psi_r2_3keV_z5[i] = ave_r2_3keV.transparency(z_re[i], 4.0)
    psi_r3_3keV_z5[i] = ave_r3_3keV.transparency(z_re[i], 4.0)
    psi_r4_3keV_z5[i] = ave_r4_3keV.transparency(z_re[i], 4.0)
    
    psi_r1_4keV_z5[i] = ave_r1_4keV.transparency(z_re[i], 4.0)
    psi_r2_4keV_z5[i] = ave_r2_4keV.transparency(z_re[i], 4.0)
    psi_r3_4keV_z5[i] = ave_r3_4keV.transparency(z_re[i], 4.0)
    psi_r4_4keV_z5[i] = ave_r4_4keV.transparency(z_re[i], 4.0)
    
    psi_r1_6keV_z5[i] = ave_r1_6keV.transparency(z_re[i], 4.0)
    psi_r2_6keV_z5[i] = ave_r2_6keV.transparency(z_re[i], 4.0)
    psi_r3_6keV_z5[i] = ave_r3_6keV.transparency(z_re[i], 4.0)
    psi_r4_6keV_z5[i] = ave_r4_6keV.transparency(z_re[i], 4.0)
    
    psi_r1_9keV_z5[i] = ave_r1_9keV.transparency(z_re[i], 4.0)
    psi_r2_9keV_z5[i] = ave_r2_9keV.transparency(z_re[i], 4.0)
    psi_r3_9keV_z5[i] = ave_r3_9keV.transparency(z_re[i], 4.0)
    psi_r4_9keV_z5[i] = ave_r4_9keV.transparency(z_re[i], 4.0)

# %%
def sample_variance_only_gadget(ave, r1, r2, r3, r4):
    "Need it for transparency stuff"
    temp = (r1 - ave)**2 + (r2 - ave)**2 + (r3 - ave)**2 + (r4 - ave)**2
    temp = np.sqrt(temp / 4.)
    return temp

# %%
# compute the errorbar
psi_error_cdm_z1 = sample_variance_only_gadget(psi_ave_cdm_z1, psi_r1_cdm_z1, psi_r2_cdm_z1, psi_r3_cdm_z1, psi_r4_cdm_z1)
psi_error_cdm_z3 = sample_variance_only_gadget(psi_ave_cdm_z3, psi_r1_cdm_z3, psi_r2_cdm_z3, psi_r3_cdm_z3, psi_r4_cdm_z3)
psi_error_cdm_z5 = sample_variance_only_gadget(psi_ave_cdm_z5, psi_r1_cdm_z5, psi_r2_cdm_z5, psi_r3_cdm_z5, psi_r4_cdm_z5)

psi_error_3keV_z1 = sample_variance_only_gadget(psi_ave_3keV_z1, psi_r1_3keV_z1, psi_r2_3keV_z1, psi_r3_3keV_z1, psi_r4_3keV_z1)
psi_error_4keV_z1 = sample_variance_only_gadget(psi_ave_4keV_z1, psi_r1_4keV_z1, psi_r2_4keV_z1, psi_r3_4keV_z1, psi_r4_4keV_z1)
psi_error_6keV_z1 = sample_variance_only_gadget(psi_ave_6keV_z1, psi_r1_6keV_z1, psi_r2_6keV_z1, psi_r3_6keV_z1, psi_r4_6keV_z1)
psi_error_9keV_z1 = sample_variance_only_gadget(psi_ave_9keV_z1, psi_r1_9keV_z1, psi_r2_9keV_z1, psi_r3_9keV_z1, psi_r4_9keV_z1)

psi_error_3keV_z3 = sample_variance_only_gadget(psi_ave_3keV_z3, psi_r1_3keV_z3, psi_r2_3keV_z3, psi_r3_3keV_z3, psi_r4_3keV_z3)
psi_error_4keV_z3 = sample_variance_only_gadget(psi_ave_4keV_z3, psi_r1_4keV_z3, psi_r2_4keV_z3, psi_r3_4keV_z3, psi_r4_4keV_z3)
psi_error_6keV_z3 = sample_variance_only_gadget(psi_ave_6keV_z3, psi_r1_6keV_z3, psi_r2_6keV_z3, psi_r3_6keV_z3, psi_r4_6keV_z3)
psi_error_9keV_z3 = sample_variance_only_gadget(psi_ave_9keV_z3, psi_r1_9keV_z3, psi_r2_9keV_z3, psi_r3_9keV_z3, psi_r4_9keV_z3)

psi_error_3keV_z5 = sample_variance_only_gadget(psi_ave_3keV_z5, psi_r1_3keV_z5, psi_r2_3keV_z5, psi_r3_3keV_z5, psi_r4_3keV_z5)
psi_error_4keV_z5 = sample_variance_only_gadget(psi_ave_4keV_z5, psi_r1_4keV_z5, psi_r2_4keV_z5, psi_r3_4keV_z5, psi_r4_4keV_z5)
psi_error_6keV_z5 = sample_variance_only_gadget(psi_ave_6keV_z5, psi_r1_6keV_z5, psi_r2_6keV_z5, psi_r3_6keV_z5, psi_r4_6keV_z5)
psi_error_9keV_z5 = sample_variance_only_gadget(psi_ave_9keV_z5, psi_r1_9keV_z5, psi_r2_9keV_z5, psi_r3_9keV_z5, psi_r4_9keV_z5)

# %%
mean_psi_z1 = np.zeros((len(z_re),n))
mean_psi_z3 = np.zeros((len(z_re),n))
mean_psi_z5 = np.zeros((len(z_re),n))
error_psi_z1 = np.zeros((len(z_re),n))
error_psi_z3 = np.zeros((len(z_re),n))
error_psi_z5 = np.zeros((len(z_re),n))

mean_psi_z1[:,0] =  psi_ave_cdm_z1[:]
mean_psi_z1[:,1] = psi_ave_9keV_z1[:]
mean_psi_z1[:,2] = psi_ave_6keV_z1[:]
mean_psi_z1[:,3] = psi_ave_4keV_z1[:]
mean_psi_z1[:,4] = psi_ave_3keV_z1[:]

mean_psi_z3[:,0] =  psi_ave_cdm_z3[:]
mean_psi_z3[:,1] = psi_ave_9keV_z3[:]
mean_psi_z3[:,2] = psi_ave_6keV_z3[:]
mean_psi_z3[:,3] = psi_ave_4keV_z3[:]
mean_psi_z3[:,4] = psi_ave_3keV_z3[:]

mean_psi_z5[:,0] =  psi_ave_cdm_z5[:]
mean_psi_z5[:,1] = psi_ave_9keV_z5[:]
mean_psi_z5[:,2] = psi_ave_6keV_z5[:]
mean_psi_z5[:,3] = psi_ave_4keV_z5[:]
mean_psi_z5[:,4] = psi_ave_3keV_z5[:]

error_psi_z1[:,0] =  psi_error_cdm_z1[:]
error_psi_z1[:,1] = psi_error_9keV_z1[:]
error_psi_z1[:,2] = psi_error_6keV_z1[:]
error_psi_z1[:,3] = psi_error_4keV_z1[:]
error_psi_z1[:,4] = psi_error_3keV_z1[:]

error_psi_z3[:,0] =  psi_error_cdm_z3[:]
error_psi_z3[:,1] = psi_error_9keV_z3[:]
error_psi_z3[:,2] = psi_error_6keV_z3[:]
error_psi_z3[:,3] = psi_error_4keV_z3[:]
error_psi_z3[:,4] = psi_error_3keV_z3[:]

error_psi_z5[:,0] =  psi_error_cdm_z5[:]
error_psi_z5[:,1] = psi_error_9keV_z5[:]
error_psi_z5[:,2] = psi_error_6keV_z5[:]
error_psi_z5[:,3] = psi_error_4keV_z5[:]
error_psi_z5[:,4] = psi_error_3keV_z5[:]

# %%
# time to plot then

fig, axs = plt.subplots(1, 3,figsize=(16,6))
for i in range(n):
    axs[0].fill_between(z_re, mean_psi_z1[:,i] - error_psi_z1[:,i], mean_psi_z1[:,i] + error_psi_z1[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
    axs[1].fill_between(z_re, mean_psi_z3[:,i] - error_psi_z3[:,i], mean_psi_z3[:,i] + error_psi_z3[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
    axs[2].fill_between(z_re, mean_psi_z5[:,i] - error_psi_z5[:,i], mean_psi_z5[:,i] + error_psi_z5[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
# axs[0].plot(z_re, psi_ave_cdm_z1, '-', color='royalblue', label=r'cdm')
# axs[0].plot(z_re, psi_ave_3keV_z1, ':', color='magenta', label=r'$m_{\rm wdm} = 3$ keV')
# axs[0].plot(z_re, psi_ave_4keV_z1, ':', color='orange', label=r'$m_{\rm wdm} = 4$ keV')
# axs[0].plot(z_re, psi_ave_6keV_z1, '--', color='purple', label=r'$m_{\rm wdm} = 6$ keV')
# axs[0].plot(z_re, psi_ave_9keV_z1, '-.', color='green', label=r'$m_{\rm wdm} = 9$ keV')
# # axs[0].fill_between(z_re, psi_ave_cdm_z1 - psi_error_cdm_z1, psi_ave_cdm_z1 + psi_error_cdm_z1, alpha=0.2, facecolor='royalblue')
# # axs[0].fill_between(z_re, psi_ave_3keV_z1 - psi_error_3keV_z1, psi_ave_3keV_z1 + psi_error_3keV_z1, alpha=0.2, facecolor='magenta')
# # axs[0].fill_between(z_re, psi_ave_4keV_z1 - psi_error_4keV_z1, psi_ave_4keV_z1 + psi_error_4keV_z1, alpha=0.2, facecolor='orange')
# # axs[0].fill_between(z_re, psi_ave_6keV_z1 - psi_error_6keV_z1, psi_ave_6keV_z1 + psi_error_6keV_z1, alpha=0.2, facecolor='purple')
# # axs[0].fill_between(z_re, psi_ave_9keV_z1 - psi_error_9keV_z1, psi_ave_9keV_z1 + psi_error_9keV_z1, alpha=0.2, facecolor='green')
axs[0].grid(linestyle='dotted')
axs[0].set_title(r'$z_{\rm obs} = 2.0$', fontsize=16)
axs[0].set_xlabel(r'$z_{\rm re}$',fontsize=16)
axs[0].set_ylabel(r'Transparency    [%]',fontsize=16)
axs[0].legend(loc='best', fontsize=14)
axs[0].tick_params(axis = 'both', which = 'major', labelsize = 14)
# next
axs[1].grid(linestyle='dotted')
axs[1].set_title(r'$z_{\rm obs} = 3.0$', fontsize=16)
axs[1].set_xlabel(r'$z_{\rm re}$',fontsize=16)
axs[1].tick_params(axis = 'both', which = 'major', labelsize = 14)
# next
# axs[1].plot(z_re, psi_ave_cdm_z5, '-', color='royalblue', label=r'cdm')
# axs[1].plot(z_re, psi_ave_3keV_z5, ':', color='magenta', label=r'$m_{\rm wdm} = 3$ keV')
# axs[1].plot(z_re, psi_ave_4keV_z5, ':', color='orange', label=r'$m_{\rm wdm} = 4$ keV')
# axs[1].plot(z_re, psi_ave_6keV_z5, '--', color='purple', label=r'$m_{\rm wdm} = 6$ keV')
# axs[1].plot(z_re, psi_ave_9keV_z5, '-.', color='green', label=r'$m_{\rm wdm} = 9$ keV')
# axs[1].fill_between(z_re, psi_ave_cdm_z5 - psi_error_cdm_z5, psi_ave_cdm_z5 + psi_error_cdm_z5, alpha=0.2, facecolor='royalblue')
# axs[1].fill_between(z_re, psi_ave_3keV_z5 - psi_error_3keV_z5, psi_ave_3keV_z5 + psi_error_3keV_z5, alpha=0.2, facecolor='magenta')
# axs[1].fill_between(z_re, psi_ave_4keV_z5 - psi_error_4keV_z5, psi_ave_4keV_z5 + psi_error_4keV_z5, alpha=0.2, facecolor='orange')
# axs[1].fill_between(z_re, psi_ave_6keV_z5 - psi_error_6keV_z5, psi_ave_6keV_z5 + psi_error_6keV_z5, alpha=0.2, facecolor='purple')
# axs[1].fill_between(z_re, psi_ave_9keV_z5 - psi_error_9keV_z5, psi_ave_9keV_z5 + psi_error_9keV_z5, alpha=0.2, facecolor='green')
axs[2].grid(linestyle='dotted')
axs[2].set_title(r'$z_{\rm obs} = 4.0$', fontsize=16)
axs[2].set_xlabel(r'$z_{\rm re}$',fontsize=16)
# axs[1].set_ylabel(r'Transparency    [%]',fontsize=16)
# axs[1].legend(loc='best', fontsize=14)
axs[2].tick_params(axis = 'both', which = 'major', labelsize = 14)
plt.savefig('transparency.pdf',bbox_inches="tight")
plt.show()

# probably fill between better for this.

# %%
# time to plot then
fig = plt.figure(figsize=(6,6))
ax1 = fig.add_subplot(111)
for i in range(n):
    ax1.fill_between(z_re, mean_psi_z5[:,i] - error_psi_z5[:,i], mean_psi_z5[:,i] + error_psi_z5[:,i], facecolor=colors[i], edgecolor=colors[i], label=labels[i])
ax1.grid(linestyle='dotted')
ax1.set_title(r'$z_{\rm obs} = 4.0$', fontsize=16)
ax1.set_xlabel(r'$z_{\rm re}$',fontsize=16)
ax1.set_ylabel(r'Transparency    [%]',fontsize=16)
ax1.legend(loc='best', fontsize=14)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)
plt.savefig('transparency_for_talk.pdf',bbox_inches="tight")
plt.show()

# %%
k_array
# Out:
# array([0.01570796, 0.02346256, 0.03503514, 0.05263151, 0.07314235,
#        0.1025928 , 0.1448116 , 0.202346  , 0.2834245 , 0.3967448 ,
#        0.5552783 , 0.7774819 , 1.088445  , 1.523711  , 2.088426  ,
#        2.685505  ])

# %%
# correlation function
r_hMpc = np.linspace(0.0,200,200)
h = 0.6774
ave_ave_cdm_xi = np.zeros((len(r_hMpc),5))
ave_ave_3keV_xi = np.zeros((len(r_hMpc),5))
# ave_ave_cdm_corr_ell0 = np.zeros(len(r_hMpc))
# ave_ave_cdm_corr_ell2 = np.zeros(len(r_hMpc))
# ave_ave_cdm_corr_ell4 = np.zeros(len(r_hMpc))
# ave_ave_cdm_reio_corr_ell0 = np.zeros(len(r_hMpc))
# ave_ave_cdm_reio_corr_ell2 = np.zeros(len(r_hMpc))
for i in range(0, len(r_hMpc)):
    ave_ave_cdm_xi[i,:] = ave_ave_cdm.correlation_components_Mpc(r_hMpc[i] / h, 4.0)
    ave_ave_3keV_xi[i,:] = ave_ave_3keV.correlation_components_Mpc(r_hMpc[i] / h, 4.0)
    print('did an r')
#     print(ave_ave_cdm_xi)

#     temp = ave_ave_cdm.correlation_components_Mpc(r_hMpc[i] / h, 3.0)
#     ave_ave_cdm_corr_ell0[i] = pow(r_hMpc[i], 2) * ave_ave_cdm.correlation_ell0_Mpc(r_hMpc[i] / h, 3.0)
#     ave_ave_cdm_corr_ell2[i] = pow(r_hMpc[i], 2) * ave_ave_cdm.correlation_ell2_Mpc(r_hMpc[i] / h, 3.0)
#     ave_ave_cdm_corr_ell4[i] = pow(r_hMpc[i], 2) * ave_ave_cdm.correlation_ell4_Mpc(r_hMpc[i] / h, 3.0)
#     ave_ave_cdm_reio_corr_ell0[i] = pow(r_hMpc[i], 2) * ave_ave_cdm.reio_corr_ell0(r_hMpc[i] / h, 3.0)
#     ave_ave_cdm_reio_corr_ell2[i] = pow(r_hMpc[i], 2) * ave_ave_cdm.reio_corr_ell2(r_hMpc[i] / h, 3.0)
    

ave_ave_cdm_total_corr = ave_ave_cdm_xi[:,0] + ave_ave_cdm_xi[:,1] + ave_ave_cdm_xi[:,2]
ave_ave_cdm_reio_total_corr = ave_ave_cdm_xi[:,3] + ave_ave_cdm_xi[:,4] + ave_ave_cdm_xi[:,2]
ave_ave_3keV_total_corr = ave_ave_3keV_xi[:,0] + ave_ave_3keV_xi[:,1] + ave_ave_3keV_xi[:,2]
ave_ave_3keV_reio_total_corr = ave_ave_3keV_xi[:,3] + ave_ave_3keV_xi[:,4] + ave_ave_3keV_xi[:,2]
# ave_ave_cdm_total_corr = ave_ave_cdm_corr_ell0[:] + ave_ave_cdm_corr_ell2[:] + ave_ave_cdm_corr_ell4[:]
# ave_ave_cdm_reio_total_corr = ave_ave_cdm_reio_corr_ell0[:] + ave_ave_cdm_reio_corr_ell2[:] + ave_ave_cdm_corr_ell4[:]
# Out:
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# did an r
# ...

# %%
# and figure
fig, axs = plt.subplots(2,2,figsize=(12,12), sharex=True)
axs[0,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,0], linestyle='dashed', label=r'Base')
axs[0,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,3], color='orange', linestyle='solid', label='Planck reio.')
axs[0,0].grid(linestyle='dotted')
axs[0,0].legend(loc='best',fontsize=14)
axs[0,0].set_ylabel(r'$r^2 \xi_0(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# next
axs[0,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,1], linestyle='dashed')
axs[0,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,4], color='orange', linestyle='solid')
axs[0,1].grid(linestyle='dotted')
axs[0,1].set_ylabel(r'$r^2 \xi_2(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# next
axs[1,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,2], linestyle='dashed')
axs[1,0].set_xlabel(r'r   [$h^{-1}$ Mpc]', fontsize=14)
axs[1,0].grid(linestyle='dotted')
axs[1,0].set_ylabel(r'$r^2 \xi_4(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# total
axs[1,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_total_corr, linestyle='dashed')
axs[1,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_reio_total_corr, color='orange', linestyle='solid')
axs[1,1].set_xlabel(r'r   [$h^{-1}$ Mpc]', fontsize=14)
axs[1,1].grid(linestyle='dotted')
axs[1,1].set_ylabel(r'$r^2(\xi_0 + \xi_2 + \xi_4$)    [$h^{-2}$ Mpc$^2$]', fontsize=14)
#fig.subplots_adjust(wspace=0.1)
plt.savefig('Correlation_cdm.pdf',bbox_inches="tight")
plt.show()

# %%
ave_ave_cdm_xi[:,3],ave_ave_3keV_xi[:,3]
# Out:
# (array([ 2.23764431e-01,  4.56095124e-02,  2.61132141e-02,  1.78640893e-02,
#          1.34650548e-02,  1.03673997e-02,  8.30679403e-03,  6.83720747e-03,
#          5.64983663e-03,  4.76631841e-03,  4.05904630e-03,  3.46839695e-03,
#          3.01596680e-03,  2.62604818e-03,  2.29311838e-03,  2.02640871e-03,
#          1.78274355e-03,  1.57540042e-03,  1.40272848e-03,  1.24220844e-03,
#          1.11006113e-03,  9.96175426e-04,  8.90048931e-04,  8.03986097e-04,
#          7.25221614e-04,  6.52567205e-04,  5.93531350e-04,  5.36612169e-04,
#          4.86030802e-04,  4.43981213e-04,  4.01835594e-04,  3.65986662e-04,
#          3.34592615e-04,  3.02883390e-04,  2.77162170e-04,  2.53226949e-04,
#          2.29933067e-04,  2.11829629e-04,  1.93831977e-04,  1.77448704e-04,
#          1.64789918e-04,  1.51308380e-04,  1.40082559e-04,  1.30940014e-04,
#          1.20810581e-04,  1.13165719e-04,  1.06132652e-04,  9.84836330e-05,
# ...

# %%
ave_ave_cdm_xi[:,2],ave_ave_3keV_xi[:,2]
# Out:
# (array([0.00000000e+00, 1.00668574e-03, 6.67418361e-04, 5.22021510e-04,
#         4.39886964e-04, 3.72245504e-04, 3.24999390e-04, 2.89354712e-04,
#         2.57454552e-04, 2.33246148e-04, 2.12581311e-04, 1.93807760e-04,
#         1.78936435e-04, 1.65267297e-04, 1.52984706e-04, 1.42852722e-04,
#         1.33127526e-04, 1.24561612e-04, 1.17162840e-04, 1.09935111e-04,
#         1.03681919e-04, 9.80078563e-05, 9.24883293e-05, 8.77484578e-05,
#         8.32446595e-05, 7.89511610e-05, 7.52348234e-05, 7.15783425e-05,
#         6.81912444e-05, 6.51884372e-05, 6.21809758e-05, 5.94722075e-05,
#         5.69813934e-05, 5.44899932e-05, 5.22884231e-05, 5.01794294e-05,
#         4.81092270e-05, 4.62871950e-05, 4.44783720e-05, 4.27551366e-05,
#         4.12164508e-05, 3.96544071e-05, 3.82139489e-05, 3.68880494e-05,
#         3.55376521e-05, 3.43252332e-05, 3.31646129e-05, 3.20008301e-05,
#         3.09686975e-05, 2.99414437e-05, 2.89412575e-05, 2.80480342e-05,
# ...

# %%
# and figure
fig, axs = plt.subplots(2,2,figsize=(12,12), sharex=True)
axs[0,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,3], linestyle='dashed', label=r'Planck+cdm')
axs[0,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_3keV_xi[:,3], color='orange', linestyle='solid', label='Planck+3keV')
axs[0,0].grid(linestyle='dotted')
axs[0,0].legend(loc='best',fontsize=14)
axs[0,0].set_ylabel(r'$r^2 \xi_0(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# next
axs[0,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,4], linestyle='dashed')
axs[0,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_3keV_xi[:,4], color='orange', linestyle='solid')
axs[0,1].grid(linestyle='dotted')
axs[0,1].set_ylabel(r'$r^2 \xi_2(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# next
axs[1,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,2], linestyle='dashed')
axs[1,0].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_3keV_xi[:,2], linestyle='dashed')
axs[1,0].set_xlabel(r'r   [$h^{-1}$ Mpc]', fontsize=14)
axs[1,0].grid(linestyle='dotted')
axs[1,0].set_ylabel(r'$r^2 \xi_4(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
# total
axs[1,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_reio_total_corr, linestyle='dashed')
axs[1,1].plot(r_hMpc, pow(r_hMpc,2)*ave_ave_3keV_reio_total_corr, color='orange', linestyle='solid')
axs[1,1].set_xlabel(r'r   [$h^{-1}$ Mpc]', fontsize=14)
axs[1,1].grid(linestyle='dotted')
axs[1,1].set_ylabel(r'$r^2(\xi_0 + \xi_2 + \xi_4$)    [$h^{-2}$ Mpc$^2$]', fontsize=14)
#fig.subplots_adjust(wspace=0.1)
plt.savefig('Correlation.pdf',bbox_inches="tight")
plt.show()

# %%
k_trapp = np.linspace(0.001, 1.4, 500)
# let's plot the integrand for fiducial and no reio
plot_reio_integrand_ell0 = np.zeros(len(k_trapp))
plot_base_integrand_ell0 = np.zeros(len(k_trapp))
plot_reio_integrand_ell2 = np.zeros(len(k_trapp))
plot_base_integrand_ell2 = np.zeros(len(k_trapp))
r_test_Mpc = 150
z_test=3.0


for i in range(0,len(k_trapp)):
    plot_base_integrand_ell0[i] = ave_ave_cdm.integ_ell0(k_trapp[i], r_test_Mpc, z_test)
    plot_base_integrand_ell2[i] = ave_ave_cdm.integ_ell2(k_trapp[i], r_test_Mpc, z_test)
    plot_reio_integrand_ell0[i] = ave_ave_cdm.reio_integ_ell0(k_trapp[i], r_test_Mpc, z_test)
    plot_reio_integrand_ell2[i] = ave_ave_cdm.reio_integ_ell2(k_trapp[i], r_test_Mpc, z_test)


fig, axs = plt.subplots(1,2,figsize=(14,6))
axs[0].plot(k_trapp, plot_base_integrand_ell0, label='Base')
axs[0].plot(k_trapp, plot_reio_integrand_ell0, label='Planck reio.')
axs[0].grid(linestyle='dotted')
axs[0].legend(loc='best',fontsize=14)
axs[0].set_ylabel(r'Integrand[$\xi_{\ell = 0}$]', fontsize=14)
axs[0].set_xlabel(r'k   [1/Mpc]', fontsize=14)
axs[1].plot(k_trapp, plot_base_integrand_ell2, label='Base')
axs[1].plot(k_trapp, plot_reio_integrand_ell2, label='Planck reio.')
axs[1].grid(linestyle='dotted')
axs[1].legend(loc='best',fontsize=14)
axs[1].set_ylabel(r'Integrand[$\xi_{\ell = 2}$]', fontsize=14)
axs[1].set_xlabel(r'k   [1/Mpc]', fontsize=14)
plt.savefig('Correlation_integrands.pdf',bbox_inches="tight")
plt.show()

# %%
# for paper I think the monopole should be enough
fig = plt.figure(figsize=(6,6))
ax1 = fig.add_subplot(111)
ax1.plot(r_hMpc, pow(r_hMpc,2)*ave_ave_cdm_xi[:,3], linestyle='dashed', label=r'Planck+cdm')
ax1.plot(r_hMpc, pow(r_hMpc,2)*ave_ave_3keV_xi[:,3], color='orange', linestyle='solid', label='Planck+3keV')
ax1.grid(linestyle='dotted')
ax1.legend(loc='best',fontsize=14)
ax1.set_ylabel(r'$r^2 \xi_0(r)$    [$h^{-2}$ Mpc$^2$]', fontsize=14)
plt.savefig('xi_monopole.pdf',bbox_inches="tight")
plt.show()

# %%
# Checking what went wrong went changed to Arinyo's modeling
# first test should be a comparison at pivot point of bias
h = 0.6774
z = 2
mu = 0.1
k = 0.1
print('flux bias:', ave_ave_cdm.flux_bias(z,0.8159))
print('rsd:', ave_ave_cdm.beta_rsd(z,0.8159))
print('kaiser term at mu = 0.1:', ave_ave_cdm.flux_bias(z,0.8159)**2 * (1. + ave_ave_cdm.beta_rsd(z, 0.8159) * mu**2))
print('Pm:', ave_ave_cdm.pm.P_m_WDM_Mpc(k / h, z))
print('PF:', ave_ave_cdm.FluxP3D_lya_Mpc(z, k, mu))
# Out:
# flux bias: [-0.0759776]
# rsd: [1.34141851]
# kaiser term at mu = 0.1: [0.00585003]
# Pm: 1838.418866658703
# PF: [10.89907366]

# %%
print('flux bias:', ave_ave_cdm.flux_bias(z,0.8778))
# Out:
# flux bias: [-0.09419825]

# %%
ave_ave_cdm.flux_bias(2.,0.8159),ave_ave_cdm.flux_bias(2.5,0.8159),ave_ave_cdm.flux_bias(3.,0.8159),ave_ave_cdm.flux_bias(3.5,0.8159),ave_ave_cdm.flux_bias(4.,0.8159)
# Out:
# (array([-0.0759776]),
#  array([-0.13404496]),
#  array([-0.21573633]),
#  array([-0.21573633]),
#  array([-0.21573633]))

# %%
print('rsd:', ave_ave_cdm.beta_rsd(z,0.8778))
# Out:
# rsd: [1.205]

# %%
mu = 0.1
print('kaiser term at mu = 0.1:', ave_ave_cdm.flux_bias(z,0.8778)**2 * (1. + ave_ave_cdm.beta_rsd(z, 0.8778) * mu**2))
# Out:
# kaiser term at mu = 0.1: [0.0408936]

# %%
(1.1424 - 1.205) / 1.205
# Out:
# -0.051950207468879656

# %%
(0.2157 - 0.2010)/ 0.2010
# Out:
# 0.0731343283582089

# %%
ave_ave_cdm.nonlinear_FluxP3D_lya_Mpc(z, k, mu, linear=False),ave_ave_cdm.FluxP3D_lya_Mpc(z, k, mu)
# Out:
# (array([73.95516382]), array([71.23835362]))

# %%
np.exp(ave_ave_cdm.log_observed_Flux(2.0)), np.exp(ave_ave_cdm.log_observed_Flux(2.5)), np.exp(ave_ave_cdm.log_observed_Flux(3.0)), np.exp(ave_ave_cdm.log_observed_Flux(3.5)), np.exp(ave_ave_cdm.log_observed_Flux(4.0))
# Out:
# (0.8808838156571367,
#  0.8004140191154157,
#  0.6959698661901971,
#  0.572853017791698,
#  0.44113463882464754)
